# %% [markdown]
# # <p style="background-color:red;font-family:arial;font-size:200%;color:white;text-align:center;border-radius:20px 20px;"><b>FOLIUM</b></p>Animate Maps with Folium: A Powerful Way to Visualize Your Data
# ![](https://media2.giphy.com/media/v1.Y2lkPTc5MGI3NjExZGZlcWkzN2Y5M2MxNjN4MWxyeTE1endkZnp5MWptajIzdXkwOHBxNCZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/UDclWKlmfmq7twI3iJ/giphy.gif)
#
# <b>If you want to be the first to be informed about new projects, please do not forget to follow us - by Fatma Nur AZMAN</b>[Linkedin](https://www.linkedin.com/in/fatma-nur-azman/) | [Kaggle](https://www.kaggle.com/fnurazman) | [Tableau](https://public.tableau.com/app/profile/fatma.nur.azman/vizzes)

# %% [markdown]
# # <font color='red'> <b> Why Folium</b><font color='red'>

# %% [markdown]
# Folium is a map visualization library developed for the Python programming language. It leverages the mapping visualization functionality using the JavaScript-based Leaflet.js library in the background. With this library, we can easily process map data and create interactive maps

# %% [markdown]
# One interesting thing about Folium maps is that they're interactive. This means that even if you set a specific zoom level at the beginning, you can zoom in on any area you're interested in to see it more clearly.

# %% [markdown]
# # <font color='red'> <b>Install & Import & Save</b><font color='red'>

# %%
#conda install -c conda-forge folium
# !pip install folium

# %%
# pip install folium --upgrade

# %%
#This command installs the Geopy library, which is used for geocoding (finding the latitude and longitude of addresses) 
# pip install geopy

# %%
import folium # Import Folium libraries

# %%
# mapname.save("mapname.html") # htm save

# %% [markdown]
# # <font color='red'> <b>Finding Location</b><font color='red'>

# %% [markdown]
# https://www.latlong.net/

# %% [markdown]
# # <font color='red'> <b>Creating a Map</b><font color='red'>

# %%
folium.Map(location=[41.0082, 28.9784])
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_44bc8018b5b40134bdaf50e1c29cbf53 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_44bc8018b5b40134bdaf50e1c29cbf53&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_44bc8018b5b40134bdaf50e1c29cbf53 = L.map(
#                 &quot;map_44bc8018b5b40134bdaf50e1c29cbf53&quot;,
#                 {
#                     center: [41.0082, 28.9784],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e540cc1d9963ed56614398bfa12c34ab = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_e540cc1d9963ed56614398bfa12c34ab.addTo(map_44bc8018b5b40134bdaf50e1c29cbf53);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Import Folium libraries
import folium
# Create a map
ist_map = folium.Map(location=[41.0082, 28.9784], zoom_start=11)
# zoom start The higher the number, the closer you get to the center.

#If you select a high number, you can see streets and alleys near your location in detail.

#If you select 1, you will see the world map with your location in the center.

# ist_map.save("ist_map.html") # puts a link to the location of the project in html

# Show Map
ist_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3168e6dc12d3c23c21e9dab3e8fbfce8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3168e6dc12d3c23c21e9dab3e8fbfce8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3168e6dc12d3c23c21e9dab3e8fbfce8 = L.map(
#                 &quot;map_3168e6dc12d3c23c21e9dab3e8fbfce8&quot;,
#                 {
#                     center: [41.0082, 28.9784],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_498f5cf19dc0ff8751e01400f2c426eb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_498f5cf19dc0ff8751e01400f2c426eb.addTo(map_3168e6dc12d3c23c21e9dab3e8fbfce8);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# - location: The field where the coordinates of the marker are specified.
#
# - popup: Description to be shown when clicking on the marker.
#
# - tooltip: Description to be shown when hovering over the marker.
#
# - icon: The icon to represent the marker.
#
# - color: The color of the icon.
#
# - You can use different icons with prefix='fa'.

# %%
# Import Folium libraries
import folium

# Adjust the coordinates of Paris
paris_coordinate = (48.8566, 2.3522)

# Create a Map
paris_map = folium.Map(location=paris_coordinate, zoom_start=11)

# Add markers to the Eiffel Tower
folium.Marker(location=(48.8584, 2.3240),
              popup='Eyfel Kulesi',
              icon=folium.Icon(color='red')).add_to(paris_map)

# Add markers to other tourist attractions
tourist_places = {
    "Louvre Müzesi": (48.8629, 2.3358),
    "Notre Dame Katedrali": (48.8651, 2.3450),
    "Zafer Takı": (48.8736, 2.2762),
    "Montmartre Tepesi": (48.8844, 2.3423),
    "Sacré-Cœur Bazilikası": (48.8860, 2.3419),
}

for ad, coordinate in tourist_places.items():
    folium.Marker(location=coordinate, popup=ad).add_to(paris_map)

# puts a link to the location of the project in html
# paris_haritasi.save("paris_haritasi.html")
# Show Map
paris_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b85518782d940a871d1afbeeb273e87b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b85518782d940a871d1afbeeb273e87b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b85518782d940a871d1afbeeb273e87b = L.map(
#                 &quot;map_b85518782d940a871d1afbeeb273e87b&quot;,
#                 {
#                     center: [48.8566, 2.3522],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_024ee453cba2729cf3fee810cf758055 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_024ee453cba2729cf3fee810cf758055.addTo(map_b85518782d940a871d1afbeeb273e87b);
#
#
#             var marker_8d7c382044d29a05befcc32945cbe768 = L.marker(
#                 [48.8584, 2.324],
#                 {}
#             ).addTo(map_b85518782d940a871d1afbeeb273e87b);
#
#
#             var icon_f0862330ff654395bc9bcb4936eb8ed6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8d7c382044d29a05befcc32945cbe768.setIcon(icon_f0862330ff654395bc9bcb4936eb8ed6);
#
#
#         var popup_bd5b603ff0de225d806daef6f1108b35 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_45343c367314ab1fd65f07a261b46107 = $(`&lt;div id=&quot;html_45343c367314ab1fd65f07a261b46107&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Eyfel Kulesi&lt;/div&gt;`)[0];
#                 popup_bd5b603ff0de225d806daef6f1108b35.setContent(html_45343c367314ab1fd65f07a261b46107);
#
#
#
#         marker_8d7c382044d29a05befcc32945cbe768.bindPopup(popup_bd5b603ff0de225d806daef6f1108b35)
#         ;
#
#
#
#
#             var marker_30cb9433f8a7b6e4145a9ec92572175f = L.marker(
#                 [48.8629, 2.3358],
#                 {}
#             ).addTo(map_b85518782d940a871d1afbeeb273e87b);
#
#
#         var popup_c1a43c4b585b6e6c171bbebe06598b6e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_eeefa9b8dfaf3ed23b6e9052e28adc67 = $(`&lt;div id=&quot;html_eeefa9b8dfaf3ed23b6e9052e28adc67&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Louvre Müzesi&lt;/div&gt;`)[0];
#                 popup_c1a43c4b585b6e6c171bbebe06598b6e.setContent(html_eeefa9b8dfaf3ed23b6e9052e28adc67);
#
#
#
#         marker_30cb9433f8a7b6e4145a9ec92572175f.bindPopup(popup_c1a43c4b585b6e6c171bbebe06598b6e)
#         ;
#
#
#
#
#             var marker_7b30db737e1951c7dda606ac85ea5eb6 = L.marker(
#                 [48.8651, 2.345],
#                 {}
#             ).addTo(map_b85518782d940a871d1afbeeb273e87b);
#
#
#         var popup_2a69407c6bf3a6a53b8b73925f79c56b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e4773e555993bfb3a31b209c74a4a723 = $(`&lt;div id=&quot;html_e4773e555993bfb3a31b209c74a4a723&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Notre Dame Katedrali&lt;/div&gt;`)[0];
#                 popup_2a69407c6bf3a6a53b8b73925f79c56b.setContent(html_e4773e555993bfb3a31b209c74a4a723);
#
#
#
#         marker_7b30db737e1951c7dda606ac85ea5eb6.bindPopup(popup_2a69407c6bf3a6a53b8b73925f79c56b)
#         ;
#
#
#
#
#             var marker_2de47c177fcbd9a89ca9bebcc02a1b03 = L.marker(
#                 [48.8736, 2.2762],
#                 {}
#             ).addTo(map_b85518782d940a871d1afbeeb273e87b);
#
#
#         var popup_1c30a9c0720e6776d49a9bcb80ea1b9d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f1d05baa5507abbd3c69521c17710ed9 = $(`&lt;div id=&quot;html_f1d05baa5507abbd3c69521c17710ed9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Zafer Takı&lt;/div&gt;`)[0];
#                 popup_1c30a9c0720e6776d49a9bcb80ea1b9d.setContent(html_f1d05baa5507abbd3c69521c17710ed9);
#
#
#
#         marker_2de47c177fcbd9a89ca9bebcc02a1b03.bindPopup(popup_1c30a9c0720e6776d49a9bcb80ea1b9d)
#         ;
#
#
#
#
#             var marker_06813dd02eb4ed607b5271c329af1b01 = L.marker(
#                 [48.8844, 2.3423],
#                 {}
#             ).addTo(map_b85518782d940a871d1afbeeb273e87b);
#
#
#         var popup_ab74469ecbb835581e12b47c6892c797 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_96a27a3f96bafa617b2010af7c700723 = $(`&lt;div id=&quot;html_96a27a3f96bafa617b2010af7c700723&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Montmartre Tepesi&lt;/div&gt;`)[0];
#                 popup_ab74469e

# %% [markdown]
# Some values the tiles parameter can take are:
#
# CartoDB Positron: This offers a modern and minimalist map style. It has grey tones, white labels, and dark borders, making it good for data visualizations.
#
# Stamen Terrain: This is a colorful map style showing natural landforms and topographic features. It highlights mountains, hills, bodies of water, and green areas.
#
# Stamen Watercolor: This has a hand-drawn style in watercolors. It highlights natural features like water, land, and vegetation, with a high artistic design.
#
# Stamen Toner: This is a black and white map style. It emphasizes details like roads, borders, and labels. It is ideal for data visualizations.
#
# CartoDB Dark Matter: This has a black background with white labels, offering a minimalist map style. It is suitable for scientific maps, visualizations, and analyses.

# %%
# Import Folium libraries
import folium

m = folium.Map(location=[45.523, -122.675], width=750, height=500)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a511d0018c7360040b943dbab86c3ac4 {
#                     position: relative;
#                     width: 750.0px;
#                     height: 500.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a511d0018c7360040b943dbab86c3ac4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a511d0018c7360040b943dbab86c3ac4 = L.map(
#                 &quot;map_a511d0018c7360040b943dbab86c3ac4&quot;,
#                 {
#                     center: [45.523, -122.675],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e0c3184aa420f5f0887b28a62aca5d71 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_e0c3184aa420f5f0887b28a62aca5d71.addTo(map_a511d0018c7360040b943dbab86c3ac4);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Import Folium libraries
import folium

m = folium.Map(location=[45.523, -122.675], tiles="cartodb positron")
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_76e69749de9052d395ba9409ef332a8c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_76e69749de9052d395ba9409ef332a8c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_76e69749de9052d395ba9409ef332a8c = L.map(
#                 &quot;map_76e69749de9052d395ba9409ef332a8c&quot;,
#                 {
#                     center: [45.523, -122.675],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_774662361ebcf1033f2418ec594a2787 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_774662361ebcf1033f2418ec594a2787.addTo(map_76e69749de9052d395ba9409ef332a8c);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Import Folium libraries
import folium

m = folium.Map(location=[45.523, -122.675], tiles="CartoDB Voyager")
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cedb9f6842e49da5e34a11fa9e63397c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cedb9f6842e49da5e34a11fa9e63397c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cedb9f6842e49da5e34a11fa9e63397c = L.map(
#                 &quot;map_cedb9f6842e49da5e34a11fa9e63397c&quot;,
#                 {
#                     center: [45.523, -122.675],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_206ffe4d27bb685cf59b6a274f763501 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/rastertiles/voyager/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_206ffe4d27bb685cf59b6a274f763501.addTo(map_cedb9f6842e49da5e34a11fa9e63397c);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Import Folium libraries
import folium

folium.Map(location=[41.0082, 28.9784], tiles="Cartodb dark_matter")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_155550fa4c923989286522b3183803d8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_155550fa4c923989286522b3183803d8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_155550fa4c923989286522b3183803d8 = L.map(
#                 &quot;map_155550fa4c923989286522b3183803d8&quot;,
#                 {
#                     center: [41.0082, 28.9784],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b5be01934a22e41d3776ae990738cf3b = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/dark_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_b5be01934a22e41d3776ae990738cf3b.addTo(map_155550fa4c923989286522b3183803d8);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ##  Adding Pop ups

# %%
# Import Folium libraries
import folium
# Create a map
ist_map = folium.Map(location=[41.0082, 28.9784], zoom_start=11)
# zoom start The higher the number, the closer you are to the center.
#If you choose a high number, you can see streets and roads near your location in detail.
#If you choose 1, you will see a world map with your location in the center.

# Add markers
folium.Marker(location=[41.0122, 28.9764],
              popup='Sultanahmet Camii').add_to(ist_map)
folium.Marker(location=[41.0554, 28.9940],
              popup='Galata Kulesi').add_to(ist_map)
folium.Marker(location=[41.0339, 28.9774], popup='Kapalıçarşı').add_to(ist_map)

# puts a link to the location of the project in html
# ist_map.save("ist_map.html")
# Show Map
ist_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0cc7c87e027145d3799e8579db1cb267 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0cc7c87e027145d3799e8579db1cb267&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0cc7c87e027145d3799e8579db1cb267 = L.map(
#                 &quot;map_0cc7c87e027145d3799e8579db1cb267&quot;,
#                 {
#                     center: [41.0082, 28.9784],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8664b026650f0cbd0faa6b62746122a4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_8664b026650f0cbd0faa6b62746122a4.addTo(map_0cc7c87e027145d3799e8579db1cb267);
#
#
#             var marker_0dfd20105c7887253f55aae2479579a2 = L.marker(
#                 [41.0122, 28.9764],
#                 {}
#             ).addTo(map_0cc7c87e027145d3799e8579db1cb267);
#
#
#         var popup_e48574ac6e6a1dc03ad9a58d2019582c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a5f2f77b966aff7848c68eff596751ae = $(`&lt;div id=&quot;html_a5f2f77b966aff7848c68eff596751ae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sultanahmet Camii&lt;/div&gt;`)[0];
#                 popup_e48574ac6e6a1dc03ad9a58d2019582c.setContent(html_a5f2f77b966aff7848c68eff596751ae);
#
#
#
#         marker_0dfd20105c7887253f55aae2479579a2.bindPopup(popup_e48574ac6e6a1dc03ad9a58d2019582c)
#         ;
#
#
#
#
#             var marker_100081557b808e896e1927db0b1f75be = L.marker(
#                 [41.0554, 28.994],
#                 {}
#             ).addTo(map_0cc7c87e027145d3799e8579db1cb267);
#
#
#         var popup_d4cd4cdbd0c376f663a51958bf583188 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ec53f2ea3b6bd0b414aaaae0ca525a83 = $(`&lt;div id=&quot;html_ec53f2ea3b6bd0b414aaaae0ca525a83&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Galata Kulesi&lt;/div&gt;`)[0];
#                 popup_d4cd4cdbd0c376f663a51958bf583188.setContent(html_ec53f2ea3b6bd0b414aaaae0ca525a83);
#
#
#
#         marker_100081557b808e896e1927db0b1f75be.bindPopup(popup_d4cd4cdbd0c376f663a51958bf583188)
#         ;
#
#
#
#
#             var marker_1d4c0701728dafae06a1b9c1fec6a054 = L.marker(
#                 [41.0339, 28.9774],
#                 {}
#             ).addTo(map_0cc7c87e027145d3799e8579db1cb267);
#
#
#         var popup_334a16bbe69288f007493a773c8b811f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_94cb9a6518462788732bb3eeb03ed94b = $(`&lt;div id=&quot;html_94cb9a6518462788732bb3eeb03ed94b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Kapalıçarşı&lt;/div&gt;`)[0];
#                 popup_334a16bbe69288f007493a773c8b811f.setContent(html_94cb9a6518462788732bb3eeb03ed94b);
#
#
#
#         marker_1d4c0701728dafae06a1b9c1fec6a054.bindPopup(popup_334a16bbe69288f007493a773c8b811f)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Adding icons

# %%
# Import Folium libraries
import folium
## Hagia Sophia coordinates
ayasofya_coordinat = [41.0084, 28.9774]

# Galata Kulesi  coordinates
galata_coordinat = [41.0257, 28.9744]

# Create a Map
ist_map = folium.Map(location=[41.0082, 28.9784], zoom_start=12)

# Add markers to the Ayasofya
ayasofya_marker = folium.Marker(location=ayasofya_coordinat,
                                popup="Ayasofya",
                                tooltip="Ayasofya Camii",
                                icon=folium.Icon(prefix='fa',
                                                 icon='fa-mosque',
                                                 color='green'))

# Add markers to the Galata Kulesi
galata_marker = folium.Marker(location=galata_coordinat,
                              popup="Galata Kulesi",
                              tooltip="Galata Kulesi",
                              icon=folium.Icon(prefix='fa',
                                               icon='fa-fort-awesome',
                                               color='blue'))

# Add markers to other tourist attractions
ayasofya_marker.add_to(ist_map)
galata_marker.add_to(ist_map)

# Show a Map
ist_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_862200c4049c900169afad4cbcf600e1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_862200c4049c900169afad4cbcf600e1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_862200c4049c900169afad4cbcf600e1 = L.map(
#                 &quot;map_862200c4049c900169afad4cbcf600e1&quot;,
#                 {
#                     center: [41.0082, 28.9784],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_47db359653f648bd5b435100a49e1734 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_47db359653f648bd5b435100a49e1734.addTo(map_862200c4049c900169afad4cbcf600e1);
#
#
#             var marker_6992755e1d4ddd6f6bb1fc1be059d939 = L.marker(
#                 [41.0084, 28.9774],
#                 {}
#             ).addTo(map_862200c4049c900169afad4cbcf600e1);
#
#
#             var icon_2d9462aa707cd341ab47748ccdc3a965 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-mosque&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_6992755e1d4ddd6f6bb1fc1be059d939.setIcon(icon_2d9462aa707cd341ab47748ccdc3a965);
#
#
#         var popup_be8edf1a3c2c1f7f27366fe205c284d5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0be3c639385145b0728c67de88eb4dd0 = $(`&lt;div id=&quot;html_0be3c639385145b0728c67de88eb4dd0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Ayasofya&lt;/div&gt;`)[0];
#                 popup_be8edf1a3c2c1f7f27366fe205c284d5.setContent(html_0be3c639385145b0728c67de88eb4dd0);
#
#
#
#         marker_6992755e1d4ddd6f6bb1fc1be059d939.bindPopup(popup_be8edf1a3c2c1f7f27366fe205c284d5)
#         ;
#
#
#
#
#             marker_6992755e1d4ddd6f6bb1fc1be059d939.bindTooltip(
#                 `&lt;div&gt;
#                      Ayasofya Camii
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_b4000658d24a93401dfd1661df32b2e7 = L.marker(
#                 [41.0257, 28.9744],
#                 {}
#             ).addTo(map_862200c4049c900169afad4cbcf600e1);
#
#
#             var icon_8d51e2b07712794315da6438c28b58c8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-fort-awesome&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_b4000658d24a93401dfd1661df32b2e7.setIcon(icon_8d51e2b07712794315da6438c28b58c8);
#
#
#         var popup_d156452a2f110c397c80a464d054fcde = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3c14ad632e01ed2de1fd5ee39e6443c4 = $(`&lt;div id=&quot;html_3c14ad632e01ed2de1fd5ee39e6443c4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Galata Kulesi&lt;/div&gt;`)[0];
#                 popup_d156452a2f110c397c80a464d054fcde.setContent(html_3c14ad632e01ed2de1fd5ee39e6443c4);
#
#
#
#         marker_b4000658d24a93401dfd1661df32b2e7.bindPopup(popup_d156452a2f110c397c80a464d054fcde)
#         ;
#
#
#
#
#             marker_b4000658d24a93401dfd1661df32b2e7.bindTooltip(
#                 `&lt;div&gt;
#                      Galata Kulesi
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Adding Tooltip

# %%
# Locations of historical monuments in Istanbul
istanbul_tarihi_eserler = {
    "Ayasofya": [41.0084, 28.9799],
    "Topkapı Sarayı": [41.0115, 28.9833],
    "Süleymaniye Camii": [41.0115, 28.9584],
    "Yerebatan Sarnıcı": [41.0085, 28.9799],
    "Galata Kulesi": [41.0257, 28.9744]
}

import folium

# Create a map centered at the coordinates [6.4516082, 3.4070867] with a zoom level of 12
m = folium.Map(location=[6.4516082, 3.4070867], zoom_start=12)

# Define a tooltip message
tooltip = "Click me tooltip"

# Add a marker to the map
folium.Marker(
    [6.4516082, 3.4070867],  # Coordinates of the marker
    popup='<strong>Location one</strong>',  # Text displayed when the marker is clicked
    tooltip=tooltip  # Tooltip message displayed when hovering over the marker
).add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_30eb1b1046df2737fd73d0fbfb551702 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_30eb1b1046df2737fd73d0fbfb551702&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_30eb1b1046df2737fd73d0fbfb551702 = L.map(
#                 &quot;map_30eb1b1046df2737fd73d0fbfb551702&quot;,
#                 {
#                     center: [6.4516082, 3.4070867],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_45ed8db9f814af498e964bd7cbad43cb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_45ed8db9f814af498e964bd7cbad43cb.addTo(map_30eb1b1046df2737fd73d0fbfb551702);
#
#
#             var marker_0f79b9fba1c1041991062e2f60c2171e = L.marker(
#                 [6.4516082, 3.4070867],
#                 {}
#             ).addTo(map_30eb1b1046df2737fd73d0fbfb551702);
#
#
#         var popup_4236202c1649964623e64a33e1e38675 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e1cd092704ec7d8e2a357f7bca2cc7b4 = $(`&lt;div id=&quot;html_e1cd092704ec7d8e2a357f7bca2cc7b4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;Location one&lt;/strong&gt;&lt;/div&gt;`)[0];
#                 popup_4236202c1649964623e64a33e1e38675.setContent(html_e1cd092704ec7d8e2a357f7bca2cc7b4);
#
#
#
#         marker_0f79b9fba1c1041991062e2f60c2171e.bindPopup(popup_4236202c1649964623e64a33e1e38675)
#         ;
#
#
#
#
#             marker_0f79b9fba1c1041991062e2f60c2171e.bindTooltip(
#                 `&lt;div&gt;
#                      Click me tooltip
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Creating Location Markers

# %%
# Import Folium libraries
import folium
# Create a Map
ist_map = folium.Map(location=[41.0082, 28.9784], zoom_start=11)

# Add markers
folium.Marker(location=[41.0122, 28.9764],
              popup='Sultanahmet Camii').add_to(ist_map)
folium.Marker(location=[41.0554, 28.9940],
              popup='Galata Kulesi').add_to(ist_map)
folium.Marker(location=[41.0339, 28.9774], popup='Kapalıçarşı').add_to(ist_map)

# Show Map
ist_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cf21aa887751d7f3941fc6d3461169ac {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cf21aa887751d7f3941fc6d3461169ac&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cf21aa887751d7f3941fc6d3461169ac = L.map(
#                 &quot;map_cf21aa887751d7f3941fc6d3461169ac&quot;,
#                 {
#                     center: [41.0082, 28.9784],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_13e1c4faadd9e723feaa89379ef58895 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_13e1c4faadd9e723feaa89379ef58895.addTo(map_cf21aa887751d7f3941fc6d3461169ac);
#
#
#             var marker_8b67d700e020183fce6aede43c457280 = L.marker(
#                 [41.0122, 28.9764],
#                 {}
#             ).addTo(map_cf21aa887751d7f3941fc6d3461169ac);
#
#
#         var popup_3464bee5b6ec35077f76f03908c8f5e2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8a7a1a2932a4082fedae7a906074c836 = $(`&lt;div id=&quot;html_8a7a1a2932a4082fedae7a906074c836&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sultanahmet Camii&lt;/div&gt;`)[0];
#                 popup_3464bee5b6ec35077f76f03908c8f5e2.setContent(html_8a7a1a2932a4082fedae7a906074c836);
#
#
#
#         marker_8b67d700e020183fce6aede43c457280.bindPopup(popup_3464bee5b6ec35077f76f03908c8f5e2)
#         ;
#
#
#
#
#             var marker_508ddf1614992b024419339650fe3940 = L.marker(
#                 [41.0554, 28.994],
#                 {}
#             ).addTo(map_cf21aa887751d7f3941fc6d3461169ac);
#
#
#         var popup_e4c31fbd1ca4568fbb7419a2ac7d4b6f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bbdd6bd1628571fdbbbab3435a2e3d17 = $(`&lt;div id=&quot;html_bbdd6bd1628571fdbbbab3435a2e3d17&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Galata Kulesi&lt;/div&gt;`)[0];
#                 popup_e4c31fbd1ca4568fbb7419a2ac7d4b6f.setContent(html_bbdd6bd1628571fdbbbab3435a2e3d17);
#
#
#
#         marker_508ddf1614992b024419339650fe3940.bindPopup(popup_e4c31fbd1ca4568fbb7419a2ac7d4b6f)
#         ;
#
#
#
#
#             var marker_6049c0e4c754c89573b1490ecdb00661 = L.marker(
#                 [41.0339, 28.9774],
#                 {}
#             ).addTo(map_cf21aa887751d7f3941fc6d3461169ac);
#
#
#         var popup_39a9098f22507efad03d6a20e7167568 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ff840be71e26eb172ee19cd92facdce6 = $(`&lt;div id=&quot;html_ff840be71e26eb172ee19cd92facdce6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Kapalıçarşı&lt;/div&gt;`)[0];
#                 popup_39a9098f22507efad03d6a20e7167568.setContent(html_ff840be71e26eb172ee19cd92facdce6);
#
#
#
#         marker_6049c0e4c754c89573b1490ecdb00661.bindPopup(popup_39a9098f22507efad03d6a20e7167568)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Import Folium libraries
import folium
# Create a Map
ist_map = folium.Map(
    location=[41.0082, 28.9784], zoom_start=11
)

# Add markers
folium.Circle(location=[41.0122, 28.9764], radius=500, color="red",
              fill=False).add_to(ist_map)

folium.CircleMarker(location=[41.0554, 28.9940],
                    radius=10,
                    color="blue",
                    fill=True,
                    fill_color="blue").add_to(ist_map)

folium.Marker(location=[41.0339, 28.9774], popup='Kapalıçarşı').add_to(ist_map)

# Show Map
ist_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7b3d021db1ff37448f1f731121664889 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7b3d021db1ff37448f1f731121664889&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7b3d021db1ff37448f1f731121664889 = L.map(
#                 &quot;map_7b3d021db1ff37448f1f731121664889&quot;,
#                 {
#                     center: [41.0082, 28.9784],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_02857db7ae8dbcbd29e94b11557ec7dc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_02857db7ae8dbcbd29e94b11557ec7dc.addTo(map_7b3d021db1ff37448f1f731121664889);
#
#
#             var circle_0b5fd77cd88e896723326782d8c3bb9f = L.circle(
#                 [41.0122, 28.9764],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 500, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7b3d021db1ff37448f1f731121664889);
#
#
#             var circle_marker_e6c8c9371d73306677f50372eca62139 = L.circleMarker(
#                 [41.0554, 28.994],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7b3d021db1ff37448f1f731121664889);
#
#
#             var marker_b558d4cf2c642966ca0c115cca18aaa7 = L.marker(
#                 [41.0339, 28.9774],
#                 {}
#             ).addTo(map_7b3d021db1ff37448f1f731121664889);
#
#
#         var popup_24d63bd35cce623bb9256272048e4b21 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cb9ba568b91f3fa3c0ab5e91703cc2a4 = $(`&lt;div id=&quot;html_cb9ba568b91f3fa3c0ab5e91703cc2a4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Kapalıçarşı&lt;/div&gt;`)[0];
#                 popup_24d63bd35cce623bb9256272048e4b21.setContent(html_cb9ba568b91f3fa3c0ab5e91703cc2a4);
#
#
#
#         marker_b558d4cf2c642966ca0c115cca18aaa7.bindPopup(popup_24d63bd35cce623bb9256272048e4b21)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Minimap

# %% [markdown]
# Minimap in the Folium library shows a small map in a corner. It helps users see the whole map and their location

# %%
# Import Folium libraries
import folium
import folium.plugins

m = folium.Map(location=[41.0151, 28.9792], zoom_start=10)
# Add Minimap
minimap = folium.plugins.MiniMap()
m.add_child(minimap)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c24d9321ad3c3d5b4eb717e757a90a5e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c24d9321ad3c3d5b4eb717e757a90a5e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c24d9321ad3c3d5b4eb717e757a90a5e = L.map(
#                 &quot;map_c24d9321ad3c3d5b4eb717e757a90a5e&quot;,
#                 {
#                     center: [41.0151, 28.9792],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_891b1ca3b22ee5edd1ebcd6393da754b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_891b1ca3b22ee5edd1ebcd6393da754b.addTo(map_c24d9321ad3c3d5b4eb717e757a90a5e);
#
#
#             var tile_layer_013e552e0b7d2cc2cbf43cf07ec4d7b8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#             var mini_map_e80fcd1f7be9d456e3b6b92c0aeb9e8e = new L.Control.MiniMap(
#                 tile_layer_013e552e0b7d2cc2cbf43cf07ec4d7b8,
#                 {&quot;autoToggleDisplay&quot;: false, &quot;centerFixed&quot;: false, &quot;collapsedHeight&quot;: 25, &quot;collapsedWidth&quot;: 25, &quot;height&quot;: 150, &quot;minimized&quot;: false, &quot;position&quot;: &quot;bottomright&quot;, &quot;toggleDisplay&quot;: false, &quot;width&quot;: 150, &quot;zoomAnimation&quot;: false, &quot;zoomLevelOffset&quot;: -5}
#             );
#             map_c24d9321ad3c3d5b4eb717e757a90a5e.addControl(mini_map_e80fcd1f7be9d456e3b6b92c0aeb9e8e);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Displaying Line Between 2 Distances

# %%
# Import the required Python libraries
import folium  # This library helps create interactive maps
from geopy.distance import geodesic  # This library calculates geographical distances

# Create a folium map centered around the given latitude and longitude with a certain zoom level
m = folium.Map([31.335432273991238, 75.53764505992153], zoom_start=6)

# Add a marker to the map with a specific location and a popup message
m.add_child(folium.Marker(location=[31.333, 75.537], popup="First Marker"))

# Create a feature group to organize map features
fg = folium.FeatureGroup(name="My map")

# Add a marker with a green color icon to the feature group
fg.add_child(
    folium.Marker(location=[32.00, 75.00],
                  popup="2nd",
                  icon=folium.Icon(color="green"))
)

# Add the feature group to the map
m.add_child(fg)

# Calculate the distance between two points in miles and convert it to kilometers
distance_miles = geodesic([31.333, 75.537], [32.00, 75.00]).miles
distance_km = distance_miles * 1.60934

# Create a polygon between two points on the map and display the calculated distance as a popup
folium.Polygon(locations=[[31.333, 75.537], [32.00, 75.00]],
               popup=f"The distance is approximately {distance_km:.2f} kilometers.",
               color='blue').add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_033108d144c4adaa8489d37aee27c870 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_033108d144c4adaa8489d37aee27c870&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_033108d144c4adaa8489d37aee27c870 = L.map(
#                 &quot;map_033108d144c4adaa8489d37aee27c870&quot;,
#                 {
#                     center: [31.335432273991238, 75.53764505992153],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c4f58ab60463da3779a9c843140e9ad1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c4f58ab60463da3779a9c843140e9ad1.addTo(map_033108d144c4adaa8489d37aee27c870);
#
#
#             var marker_2908aabc9b251278b9ff1160c14a20b7 = L.marker(
#                 [31.333, 75.537],
#                 {}
#             ).addTo(map_033108d144c4adaa8489d37aee27c870);
#
#
#         var popup_297eb4bb307707fa7a5e4b3716ce52fb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7b2b5a432ab2406225924889686bc8d8 = $(`&lt;div id=&quot;html_7b2b5a432ab2406225924889686bc8d8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;First Marker&lt;/div&gt;`)[0];
#                 popup_297eb4bb307707fa7a5e4b3716ce52fb.setContent(html_7b2b5a432ab2406225924889686bc8d8);
#
#
#
#         marker_2908aabc9b251278b9ff1160c14a20b7.bindPopup(popup_297eb4bb307707fa7a5e4b3716ce52fb)
#         ;
#
#
#
#
#             var feature_group_1c3f720f31f1074b1f0fa63663c00c63 = L.featureGroup(
#                 {}
#             );
#
#
#             var marker_6d75b513dfc65e5855106bea0f134b05 = L.marker(
#                 [32.0, 75.0],
#                 {}
#             ).addTo(feature_group_1c3f720f31f1074b1f0fa63663c00c63);
#
#
#             var icon_d3695734af2398ca93e72fcbbf2227b9 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_6d75b513dfc65e5855106bea0f134b05.setIcon(icon_d3695734af2398ca93e72fcbbf2227b9);
#
#
#         var popup_1f0dfcc3378b85f015ae8d796afea139 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2128c2fa68cb5585a724d1121e1f3795 = $(`&lt;div id=&quot;html_2128c2fa68cb5585a724d1121e1f3795&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;2nd&lt;/div&gt;`)[0];
#                 popup_1f0dfcc3378b85f015ae8d796afea139.setContent(html_2128c2fa68cb5585a724d1121e1f3795);
#
#
#
#         marker_6d75b513dfc65e5855106bea0f134b05.bindPopup(popup_1f0dfcc3378b85f015ae8d796afea139)
#         ;
#
#
#
#
#             feature_group_1c3f720f31f1074b1f0fa63663c00c63.addTo(map_033108d144c4adaa8489d37aee27c870);
#
#
#             var polygon_d657154a9396c6b31e9871edd02bb856 = L.polygon(
#                 [[31.333, 75.537], [32.0, 75.0]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_033108d144c4adaa8489d37aee27c870);
#
#
#         var popup_94404accd4c37ad0c17d5457ae900d33 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_97b11514769e9c145ddd95fc3c76ce1f = $(`&lt;div id=&quot;html_97b11514769e9c145ddd95fc3c76ce1f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;The distance is approximately 89.79 kilometers.&lt;/div&gt;`)[0];
#                 popup_94404accd4c37ad0c17d5457ae900d33.setContent(html_97b11514769e9c145ddd95fc3c76ce1f);
#
#
#
#         polygon_d657154a9396c6b31e9871edd02bb856.bindPopup(popup_94404accd4c37ad0c17d5457ae900d33)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Import Folium libraries
import folium
# Create a folium map
m = folium.Map(location=[41.015, 28.979], zoom_start=13)

# Define locations for the route guidance
locations = [
    [41.0054, 28.9767],  # Starting point coordinates
    [41.0257, 28.9744],  # Intermediate point coordinates
    [41.0368, 28.9850]  # Ending point coordinates
]

# Create a PolyLine to display the route guidance
folium.PolyLine(locations=locations, color="red").add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ddbc27e6243d0e3f9fa88353390c8645 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ddbc27e6243d0e3f9fa88353390c8645&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ddbc27e6243d0e3f9fa88353390c8645 = L.map(
#                 &quot;map_ddbc27e6243d0e3f9fa88353390c8645&quot;,
#                 {
#                     center: [41.015, 28.979],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_01dd752589abcf30fa14ca567902c86f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_01dd752589abcf30fa14ca567902c86f.addTo(map_ddbc27e6243d0e3f9fa88353390c8645);
#
#
#             var poly_line_86cdadce71c12ed3a0e8c77022f49daf = L.polyline(
#                 [[41.0054, 28.9767], [41.0257, 28.9744], [41.0368, 28.985]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ddbc27e6243d0e3f9fa88353390c8645);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Measuring Distance Between Locations

# %%
# Import Folium libraries
import folium
from folium.plugins import MeasureControl

# Create the map
istanbul_map = folium.Map(location=[41.015137, 28.979530], zoom_start=12)

# Add the MeasureControl plugin
folium.plugins.MeasureControl(position="topleft", primary_length_unit="kilometers",
                              primary_area_unit="hectares", active_color="red",
                              style={"color":"#ff0000", "linecolor":"red"}).add_to(istanbul_map)

# Display the map
istanbul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1fd33b700c5136bb5c87c05ab4c45d57 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/ljagis/leaflet-measure@2.1.7/dist/leaflet-measure.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/ljagis/leaflet-measure@2.1.7/dist/leaflet-measure.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1fd33b700c5136bb5c87c05ab4c45d57&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1fd33b700c5136bb5c87c05ab4c45d57 = L.map(
#                 &quot;map_1fd33b700c5136bb5c87c05ab4c45d57&quot;,
#                 {
#                     center: [41.015137, 28.97953],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_70fa2a67bf8811a4fe11b3aa786af0cc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_70fa2a67bf8811a4fe11b3aa786af0cc.addTo(map_1fd33b700c5136bb5c87c05ab4c45d57);
#
#
#             var measure_control_eaa078951bc8fc77be8f658949c57b39 = new L.Control.Measure(
#                 {&quot;activeColor&quot;: &quot;red&quot;, &quot;position&quot;: &quot;topleft&quot;, &quot;primaryAreaUnit&quot;: &quot;hectares&quot;, &quot;primaryLengthUnit&quot;: &quot;kilometers&quot;, &quot;secondaryAreaUnit&quot;: &quot;acres&quot;, &quot;secondaryLengthUnit&quot;: &quot;miles&quot;, &quot;style&quot;: {&quot;color&quot;: &quot;#ff0000&quot;, &quot;linecolor&quot;: &quot;red&quot;}});
#             map_1fd33b700c5136bb5c87c05ab4c45d57.addControl(measure_control_eaa078951bc8fc77be8f658949c57b39);
#
#             // Workaround for using this plugin with Leaflet&gt;=1.8.0
#             // https://github.com/ljagis/leaflet-measure/issues/171
#             L.Control.Measure.include({
#                 _setCaptureMarkerIcon: function () {
#                     // disable autopan
#                     this._captureMarker.options.autoPanOnFocus = false;
#                     // default function
#                     this._captureMarker.setIcon(
#                         L.divIcon({
#                             iconSize: this._map.getSize().multiplyBy(2)
#                         })
#                     );
#                 },
#             });
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Grouping Distant Markers

# %%
# Import Python libraries
import folium
from folium.plugins import MarkerCluster

# Create the map
m = folium.Map(location=[41.0082, 28.9784], zoom_start=11)

# Create a MarkerCluster
marker_cluster = MarkerCluster().add_to(m)

# Sample locations
locations = [[41.0122, 28.9764, 'Sultanahmet Mosque'], [41.0554, 28.9940, 'Galata Tower'], [41.0339, 28.9774, 'Grand Bazaar']]

# Create a Marker for each location and add it to the MarkerCluster
for location in locations:
    marker = folium.Marker(location=location[:2], popup=location[2])
    marker.add_to(marker_cluster)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7f6de3092f3d6ef8dd7f2eade6b2f56e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7f6de3092f3d6ef8dd7f2eade6b2f56e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7f6de3092f3d6ef8dd7f2eade6b2f56e = L.map(
#                 &quot;map_7f6de3092f3d6ef8dd7f2eade6b2f56e&quot;,
#                 {
#                     center: [41.0082, 28.9784],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b9bf203d21f086663c93a16b1ae39baa = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_b9bf203d21f086663c93a16b1ae39baa.addTo(map_7f6de3092f3d6ef8dd7f2eade6b2f56e);
#
#
#             var marker_cluster_754a6ee7bf7df947f3f53f6579de39f9 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_2cb9ec7c4f3a0d67de61ca7cb4614acb = L.marker(
#                 [41.0122, 28.9764],
#                 {}
#             ).addTo(marker_cluster_754a6ee7bf7df947f3f53f6579de39f9);
#
#
#         var popup_1acbab5660a27f6f813378ff96e5e36f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3c7b83b0f3212d09129c8be2f3104b1b = $(`&lt;div id=&quot;html_3c7b83b0f3212d09129c8be2f3104b1b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sultanahmet Mosque&lt;/div&gt;`)[0];
#                 popup_1acbab5660a27f6f813378ff96e5e36f.setContent(html_3c7b83b0f3212d09129c8be2f3104b1b);
#
#
#
#         marker_2cb9ec7c4f3a0d67de61ca7cb4614acb.bindPopup(popup_1acbab5660a27f6f813378ff96e5e36f)
#         ;
#
#
#
#
#             var marker_0fc5db868cae3cbaed7ea867c0e2c707 = L.marker(
#                 [41.0554, 28.994],
#                 {}
#             ).addTo(marker_cluster_754a6ee7bf7df947f3f53f6579de39f9);
#
#
#         var popup_ea60e88b42ca6683f410e9d6318da9a8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_38fe742738fd145ccc8348928cd8a4f5 = $(`&lt;div id=&quot;html_38fe742738fd145ccc8348928cd8a4f5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Galata Tower&lt;/div&gt;`)[0];
#                 popup_ea60e88b42ca6683f410e9d6318da9a8.setContent(html_38fe742738fd145ccc8348928cd8a4f5);
#
#
#
#         marker_0fc5db868cae3cbaed7ea867c0e2c707.bindPopup(popup_ea60e88b42ca6683f410e9d6318da9a8)
#         ;
#
#
#
#
#             var marker_3a7e56bc895bf29c20c6ec69b9142981 = L.marker(
#                 [41.0339, 28.9774],
#                 {}
#             ).addTo(marker_cluster_754a6ee7bf7df947f3f53f6579de39f9);
#
#
#         var popup_0a9f9e59dc98a2713182d474238801e4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8549f6b33f9664cd1c32147837e4067c = $(`&lt;div id=&quot;html_8549f6b33f9664cd1c32147837e4067c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Grand Bazaar&lt;/div&gt;`)[0];
#                 popup_0a9f9e59dc98a2713182d474238801e4.setContent(html_8549f6b33f9664cd1c32147837e4067c);
#
#
#
#         marker_3a7e56bc895bf29c20c6ec69b9142981.bindPopup(popup_0a9f9e59dc98a2713182d474238801e4)
#         ;
#
#
#
#
#             marker_cluster_754a6ee7bf7df947f3f53f6579de39f9.addTo(map_7f6de3092f3d6ef8dd7f2eade6b2f56e);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Creating a Heatmap

# %%
# Import Folium libraries
import folium
from folium.plugins import HeatMap

# Create the map
istanbul_map = folium.Map(location=[41.0082, 28.9784], zoom_start=12)

# Coordinates of historical sites in Istanbul
tourist_coords = [
    [41.0084, 28.9799],  # Hagia Sophia
    [41.0115, 28.9833],  # Topkapi Palace
    [41.0115, 28.9584],  # Blue Mosque
    [41.0085, 28.9799],  # Basilica Cistern
    [41.0257, 28.9744]   # Galata Tower
]

# Create and add HeatMap layer to the map
HeatMap(data=tourist_coords, radius=15).add_to(istanbul_map)

# Display the map
istanbul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_64a38c4821ac4c3512a6e7760a5021f7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_64a38c4821ac4c3512a6e7760a5021f7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_64a38c4821ac4c3512a6e7760a5021f7 = L.map(
#                 &quot;map_64a38c4821ac4c3512a6e7760a5021f7&quot;,
#                 {
#                     center: [41.0082, 28.9784],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_16f67eca22cc991e4fdf614ea3a6b66c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_16f67eca22cc991e4fdf614ea3a6b66c.addTo(map_64a38c4821ac4c3512a6e7760a5021f7);
#
#
#             var heat_map_c2aadf9343fe67216c018cb6d08f9b36 = L.heatLayer(
#                 [[41.0084, 28.9799], [41.0115, 28.9833], [41.0115, 28.9584], [41.0085, 28.9799], [41.0257, 28.9744]],
#                 {&quot;blur&quot;: 15, &quot;maxZoom&quot;: 18, &quot;minOpacity&quot;: 0.5, &quot;radius&quot;: 15}
#             );
#
#
#             heat_map_c2aadf9343fe67216c018cb6d08f9b36.addTo(map_64a38c4821ac4c3512a6e7760a5021f7);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Import Folium libraries
import folium
from folium.plugins import HeatMap

# Coordinates of historical sites in Istanbul
istanbul_historical_sites = {
    "Hagia Sophia": [41.0084, 28.9799],
    "Topkapi Palace": [41.0115, 28.9833],
    "Suleymaniye Mosque": [41.0115, 28.9584],
    "Basilica Cistern": [41.0085, 28.9799],
    "Galata Tower": [41.0257, 28.9744]
}

# Create the map
istanbul_map = folium.Map(location=[41.0082, 28.9784], zoom_start=12)

# Generate HeatMap data
heat_data = [[location[0], location[1]] for location in istanbul_historical_sites.values()]

# Create and add HeatMap layer to the map
HeatMap(heat_data).add_to(istanbul_map)

# Display the map
istanbul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fbff6a3471ad5cbda30cb5f019afa9b1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fbff6a3471ad5cbda30cb5f019afa9b1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fbff6a3471ad5cbda30cb5f019afa9b1 = L.map(
#                 &quot;map_fbff6a3471ad5cbda30cb5f019afa9b1&quot;,
#                 {
#                     center: [41.0082, 28.9784],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_790562ff7451840a465eb119d61888d1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_790562ff7451840a465eb119d61888d1.addTo(map_fbff6a3471ad5cbda30cb5f019afa9b1);
#
#
#             var heat_map_93a75bf40ce71e0bfa19bca015fe2460 = L.heatLayer(
#                 [[41.0084, 28.9799], [41.0115, 28.9833], [41.0115, 28.9584], [41.0085, 28.9799], [41.0257, 28.9744]],
#                 {&quot;blur&quot;: 15, &quot;maxZoom&quot;: 18, &quot;minOpacity&quot;: 0.5, &quot;radius&quot;: 25}
#             );
#
#
#             heat_map_93a75bf40ce71e0bfa19bca015fe2460.addTo(map_fbff6a3471ad5cbda30cb5f019afa9b1);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Location Search Feature

# %% [markdown]
# The Geocoder plugin is added to the map to enable location search functionality.
# - collapsed parameter determines whether the search box is open or closed. If set to
# - False, the search box is open by default.
# -  position parameter sets the position of the search box on the map. It can be set to values like "topleft", "topright", "bottomleft", "bottomright".
# - add_marker parameter determines whether search results are marked on the map. If set to True, the search results are marked.

# %%
# Import Folium libraries
import folium

# Create the map
m = folium.Map(location=[41.015, 28.979], zoom_start=13)

# Add Geocoder plugin to enable location search on the map
folium.plugins.Geocoder(collapsed=False, position="topleft", add_marker=True).add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ded18687f5823505c087397cbdb8c191 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ded18687f5823505c087397cbdb8c191&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ded18687f5823505c087397cbdb8c191 = L.map(
#                 &quot;map_ded18687f5823505c087397cbdb8c191&quot;,
#                 {
#                     center: [41.015, 28.979],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3fbca4a49af3b28c027721dff61ce7d4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_3fbca4a49af3b28c027721dff61ce7d4.addTo(map_ded18687f5823505c087397cbdb8c191);
#
#
#
#             var geocoderOpts_geocoder_2640872b1881a8bff464329cd27e365b = {&quot;collapsed&quot;: false, &quot;defaultMarkGeocode&quot;: true, &quot;position&quot;: &quot;topleft&quot;, &quot;provider&quot;: &quot;nominatim&quot;, &quot;providerOptions&quot;: {}, &quot;zoom&quot;: 11};
#
#             // note: geocoder name should start with lowercase
#             var geocoderName_geocoder_2640872b1881a8bff464329cd27e365b = geocoderOpts_geocoder_2640872b1881a8bff464329cd27e365b[&quot;provider&quot;];
#
#             var customGeocoder_geocoder_2640872b1881a8bff464329cd27e365b = L.Control.Geocoder[ geocoderName_geocoder_2640872b1881a8bff464329cd27e365b ](
#                 geocoderOpts_geocoder_2640872b1881a8bff464329cd27e365b[&#x27;providerOptions&#x27;]
#             );
#             geocoderOpts_geocoder_2640872b1881a8bff464329cd27e365b[&quot;geocoder&quot;] = customGeocoder_geocoder_2640872b1881a8bff464329cd27e365b;
#
#             L.Control.geocoder(
#                 geocoderOpts_geocoder_2640872b1881a8bff464329cd27e365b
#             ).on(&#x27;markgeocode&#x27;, function(e) {
#                 var zoom = geocoderOpts_geocoder_2640872b1881a8bff464329cd27e365b[&#x27;zoom&#x27;] || map_ded18687f5823505c087397cbdb8c191.getZoom();
#                 map_ded18687f5823505c087397cbdb8c191.setView(e.geocode.center, zoom);
#             }).addTo(map_ded18687f5823505c087397cbdb8c191);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Full-Screen View of the Map

# %% [markdown]
# The FullscreenControl plugin is added to the map to enable fullscreen functionality. It adds a button on the map that allows users to view the map in fullscreen mode.
# position parameter sets the position of the fullscreen button on the map. It is set to 'topright', meaning the button will appear at the top right corner of the map.

# %%
import folium
from folium import plugins

# Create the map
istanbul_map = folium.Map(location=[41.015137, 28.979530], zoom_start=12)

# Add Fullscreen plugin
plugins.Fullscreen().add_to(istanbul_map)

# Display the map
istanbul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b9b65f029023db113a9d6518a77cc373 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b9b65f029023db113a9d6518a77cc373&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b9b65f029023db113a9d6518a77cc373 = L.map(
#                 &quot;map_b9b65f029023db113a9d6518a77cc373&quot;,
#                 {
#                     center: [41.015137, 28.97953],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_badd810bd423a59292b9680126a90454 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_badd810bd423a59292b9680126a90454.addTo(map_b9b65f029023db113a9d6518a77cc373);
#
#
#             L.control.fullscreen(
#                 {&quot;forceSeparateButton&quot;: false, &quot;position&quot;: &quot;topleft&quot;, &quot;title&quot;: &quot;Full Screen&quot;, &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;}
#             ).addTo(map_b9b65f029023db113a9d6518a77cc373);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Add Fullscreen Plugin: We add the Fullscreen plugin to the map using the plugins.Fullscreen().add_to() method. This plugin adds a button to the map interface, allowing users to view the map in fullscreen mode.

# %% [markdown]
# ## Adding Drawing Tools

# %% [markdown]
# Add Drawing Tools: We add drawing tools to the map using plugins.Draw(export=True). This provides users with the ability to draw shapes on the map.

# %%
# Import Folium libraries
import folium
from folium import plugins

# Create a new map
m = folium.Map(location=[40.7128, -74.0060], zoom_start=10)

# Add drawing tools
draw = plugins.Draw(export=True)
# folium.Draw(): Provides drawing tools to users.

draw.add_to(m)

# Show the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0272d6c2bf4097d2ba2c5cd632103137 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#
#             &lt;style&gt;
#                 #export {
#                     position: absolute;
#                     top: 5px;
#                     right: 10px;
#                     z-index: 999;
#                     background: white;
#                     color: black;
#                     padding: 6px;
#                     border-radius: 4px;
#                     font-family: &#x27;Helvetica Neue&#x27;;
#                     cursor: pointer;
#                     font-size: 12px;
#                     text-decoration: none;
#                     top: 90px;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0272d6c2bf4097d2ba2c5cd632103137&quot; &gt;&lt;/div&gt;
#
#     &lt;a href=&#x27;#&#x27; id=&#x27;export&#x27;&gt;Export&lt;/a&gt;
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0272d6c2bf4097d2ba2c5cd632103137 = L.map(
#                 &quot;map_0272d6c2bf4097d2ba2c5cd632103137&quot;,
#                 {
#                     center: [40.7128, -74.006],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_73318483d4774779438c02fcae515605 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_73318483d4774779438c02fcae515605.addTo(map_0272d6c2bf4097d2ba2c5cd632103137);
#
#
#             var options = {
#               position: &quot;topleft&quot;,
#               draw: {},
#               edit: {},
#             }
#             // FeatureGroup is to store editable layers.
#             var drawnItems_draw_control_e8b1cbd24d53ae6f516645c56f4be1bc = new L.featureGroup().addTo(
#                 map_0272d6c2bf4097d2ba2c5cd632103137
#             );
#             options.edit.featureGroup = drawnItems_draw_control_e8b1cbd24d53ae6f516645c56f4be1bc;
#             var draw_control_e8b1cbd24d53ae6f516645c56f4be1bc = new L.Control.Draw(
#                 options
#             ).addTo( map_0272d6c2bf4097d2ba2c5cd632103137 );
#             map_0272d6c2bf4097d2ba2c5cd632103137.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 drawnItems_draw_control_e8b1cbd24d53ae6f516645c56f4be1bc.addLayer(layer);
#              });
#             map_0272d6c2bf4097d2ba2c5cd632103137.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems_draw_control_e8b1cbd24d53ae6f516645c56f4be1bc.addLayer(e.layer);
#             });
#
#             document.getElementById(&#x27;export&#x27;).onclick = function(e) {
#                 var data = drawnItems_draw_control_e8b1cbd24d53ae6f516645c56f4be1bc.toGeoJSON();
#                 var convertedData = &#x27;text/json;charset=utf-8,&#x27;
#                     + encodeURIComponent(JSON.stringify(data));
#                 document.getElementById(&#x27;export&#x27;).setAttribute(
#                     &#x27;href&#x27;, &#x27;data:&#x27; + convertedData
#                 );
#                 document.getElementById(&#x27;export&#x27;).setAttribute(
#                     &#x27;download&#x27;, &quot;data.geojson&quot;
#                 );
#             }
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # <font color='red'> <b>In which areas are our customers concentrated in New York?</b><font color='red'>

# %%
# Import Folium libraries
import folium

# Create a New York map
new_york_map = folium.Map(location=[40.7128, -74.0060], zoom_start=10)

# Dictionary of region coordinates
region_coordinates = {
    "Queens": (40.7282, -73.7949),
    "Manhattan": (40.7831, -73.9712),
    "Brooklyn": (40.6782, -73.9442),
    "Bronx": (40.8448, -73.8648),
    "Staten Island": (40.5795, -74.1502)
}

# Add customer data to the map
for customer in customers:
    # If the region is in the coordinates dictionary, add a marker to the map
    if customer["region"] in region_coordinates:
        folium.Marker(location=region_coordinates[customer["region"]], 
                      popup=f"{customer['customer_id']} - {customer['region']}").add_to(new_york_map)

# Show the map
new_york_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7409e235b040b692d50b65abe354b38f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7409e235b040b692d50b65abe354b38f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7409e235b040b692d50b65abe354b38f = L.map(
#                 &quot;map_7409e235b040b692d50b65abe354b38f&quot;,
#                 {
#                     center: [40.7128, -74.006],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9ceb52e70bf43dacdc9789e5c180c919 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_9ceb52e70bf43dacdc9789e5c180c919.addTo(map_7409e235b040b692d50b65abe354b38f);
#
#
#             var marker_4df07f0956034eb8ae4f25d20244f1d1 = L.marker(
#                 [40.7282, -73.7949],
#                 {}
#             ).addTo(map_7409e235b040b692d50b65abe354b38f);
#
#
#         var popup_3a0f7eb47384cf7cc1229dea7ceec39c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c6c93e8b0d431019ccef703cfbd6cc8d = $(`&lt;div id=&quot;html_c6c93e8b0d431019ccef703cfbd6cc8d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1 - Queens&lt;/div&gt;`)[0];
#                 popup_3a0f7eb47384cf7cc1229dea7ceec39c.setContent(html_c6c93e8b0d431019ccef703cfbd6cc8d);
#
#
#
#         marker_4df07f0956034eb8ae4f25d20244f1d1.bindPopup(popup_3a0f7eb47384cf7cc1229dea7ceec39c)
#         ;
#
#
#
#
#             var marker_9f94859ce3867458260af79c165012f3 = L.marker(
#                 [40.7831, -73.9712],
#                 {}
#             ).addTo(map_7409e235b040b692d50b65abe354b38f);
#
#
#         var popup_d03975a6573273d2fb8b3c3067809e97 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cb173fa9db32c43c03eb84f939f090f7 = $(`&lt;div id=&quot;html_cb173fa9db32c43c03eb84f939f090f7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;2 - Manhattan&lt;/div&gt;`)[0];
#                 popup_d03975a6573273d2fb8b3c3067809e97.setContent(html_cb173fa9db32c43c03eb84f939f090f7);
#
#
#
#         marker_9f94859ce3867458260af79c165012f3.bindPopup(popup_d03975a6573273d2fb8b3c3067809e97)
#         ;
#
#
#
#
#             var marker_df78db50f4f030c1027938499c904146 = L.marker(
#                 [40.6782, -73.9442],
#                 {}
#             ).addTo(map_7409e235b040b692d50b65abe354b38f);
#
#
#         var popup_4a36e144eb10032c8d96c1e041016eef = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_042517b9b35dde67fac219474b419d86 = $(`&lt;div id=&quot;html_042517b9b35dde67fac219474b419d86&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;3 - Brooklyn&lt;/div&gt;`)[0];
#                 popup_4a36e144eb10032c8d96c1e041016eef.setContent(html_042517b9b35dde67fac219474b419d86);
#
#
#
#         marker_df78db50f4f030c1027938499c904146.bindPopup(popup_4a36e144eb10032c8d96c1e041016eef)
#         ;
#
#
#
#
#             var marker_4adf93d609ac0d3d03e0d31fbf5bfa70 = L.marker(
#                 [40.7282, -73.7949],
#                 {}
#             ).addTo(map_7409e235b040b692d50b65abe354b38f);
#
#
#         var popup_777564550b583e8feec034ea1f464042 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8c746e4a52a36039f3c6c7565352b2cc = $(`&lt;div id=&quot;html_8c746e4a52a36039f3c6c7565352b2cc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;4 - Queens&lt;/div&gt;`)[0];
#                 popup_777564550b583e8feec034ea1f464042.setContent(html_8c746e4a52a36039f3c6c7565352b2cc);
#
#
#
#         marker_4adf93d609ac0d3d03e0d31fbf5bfa70.bindPopup(popup_777564550b583e8feec034ea1f464042)
#         ;
#
#
#
#
#             var marker_32932110a4f35a42aa62ddb2ae35baa4 = L.marker(
#                 [40.7831, -73.9712],
#                 {}
#             ).addTo(map_7409e235b040b692d50b65abe354b38f);
#
#
#         var popup_bafd84d6a1bd961e6cef44a11dbe6d03 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_780e0071c4d6d568954b23bf29f747f4 = $(`&lt;div id=&quot;html_780e0071c4d6d568954b23bf29f747f4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;5 - Manhattan&lt;/div&gt;`)[0];
#                 popup_bafd84d6a1bd961e6cef44a11dbe6d03.setContent(html_780e0071c4d6d568954b23bf29f747f4);
#
#
#
#         marker_32932110a4f35a42aa62ddb2ae35baa4.bindPopup(popup_bafd84d6a1bd961e6cef44a11dbe6d03)
#         ;
#
#
#
#
#             var marker_46519155d9f34d9e36805bcc959b612a = L.marker(
#                 [40.8448, -73.8648],
#                 {}
#             ).addTo(map_7409e235b040b692d50b65abe354b38f);
#
#
#         var popup_84a

# %% [markdown]
# # <font color='red'> <b>What are the 5 most visited tourist destinations in Spain?</b><font color='red'>

# %%
# List of 5 most visited places in Spain
places_to_visit = [
    {"place_name": "Sagrada Familia", "region": "Barcelona", "latitude": 41.4036, "longitude": 2.1743},
    {"place_name": "Alhambra", "region": "Granada", "latitude": 38.9719, "longitude": -3.8915},
    {"place_name": "Prado Museum", "region": "Madrid", "latitude": 40.4167, "longitude": -3.6833},
    {"place_name": "Park Güell", "region": "Barcelona", "latitude": 41.4036, "longitude": 2.1606},
    {"place_name": "Guggenheim Museum Bilbao", "region": "Bilbao", "latitude": 43.2609, "longitude": -2.9257},
]



# Import the Folium library and pandas
import folium
import pandas as pd

# Convert the list of places to a pandas DataFrame
data = pd.DataFrame(places_to_visit)

# Set the coordinates of Spain
spain_coordinates = (40.4002, -3.7501)

# Create a map
spain_map = folium.Map(location=spain_coordinates, zoom_start=6)

# Add the data to the map
for index, row in data.iterrows():
    folium.Marker(location=[row["latitude"], row["longitude"]], 
                  popup=f"{row['place_name']} ({row['region']})").add_to(spain_map)

# Save the map
# spain_map.save("spain_places_to_visit.html")

spain_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7b6f6e2f658f73b0b963e82c57f753cd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7b6f6e2f658f73b0b963e82c57f753cd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7b6f6e2f658f73b0b963e82c57f753cd = L.map(
#                 &quot;map_7b6f6e2f658f73b0b963e82c57f753cd&quot;,
#                 {
#                     center: [40.4002, -3.7501],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_17a6d017ce7d33c67e867225bcd4ac32 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_17a6d017ce7d33c67e867225bcd4ac32.addTo(map_7b6f6e2f658f73b0b963e82c57f753cd);
#
#
#             var marker_3fe44e377f78d993ab76f45a96579e7f = L.marker(
#                 [41.4036, 2.1743],
#                 {}
#             ).addTo(map_7b6f6e2f658f73b0b963e82c57f753cd);
#
#
#         var popup_92cf165a02e6750d69722a9588d2d1ab = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2050c93e00fe8db681fafb4b5bb709e7 = $(`&lt;div id=&quot;html_2050c93e00fe8db681fafb4b5bb709e7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sagrada Familia (Barcelona)&lt;/div&gt;`)[0];
#                 popup_92cf165a02e6750d69722a9588d2d1ab.setContent(html_2050c93e00fe8db681fafb4b5bb709e7);
#
#
#
#         marker_3fe44e377f78d993ab76f45a96579e7f.bindPopup(popup_92cf165a02e6750d69722a9588d2d1ab)
#         ;
#
#
#
#
#             var marker_0d94ea1938140b6e919af060fd896951 = L.marker(
#                 [38.9719, -3.8915],
#                 {}
#             ).addTo(map_7b6f6e2f658f73b0b963e82c57f753cd);
#
#
#         var popup_933f66053dc63917e301acecc4d0b04d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ca2fc52fdaaa64b598f9a09eb59d302e = $(`&lt;div id=&quot;html_ca2fc52fdaaa64b598f9a09eb59d302e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Alhambra (Granada)&lt;/div&gt;`)[0];
#                 popup_933f66053dc63917e301acecc4d0b04d.setContent(html_ca2fc52fdaaa64b598f9a09eb59d302e);
#
#
#
#         marker_0d94ea1938140b6e919af060fd896951.bindPopup(popup_933f66053dc63917e301acecc4d0b04d)
#         ;
#
#
#
#
#             var marker_34ca8cafb306e915729ee63fead4a825 = L.marker(
#                 [40.4167, -3.6833],
#                 {}
#             ).addTo(map_7b6f6e2f658f73b0b963e82c57f753cd);
#
#
#         var popup_01d242029e2fcba3361c27a6d53afbd2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4639b1020d0e6ae9d546da0c47176daf = $(`&lt;div id=&quot;html_4639b1020d0e6ae9d546da0c47176daf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Prado Museum (Madrid)&lt;/div&gt;`)[0];
#                 popup_01d242029e2fcba3361c27a6d53afbd2.setContent(html_4639b1020d0e6ae9d546da0c47176daf);
#
#
#
#         marker_34ca8cafb306e915729ee63fead4a825.bindPopup(popup_01d242029e2fcba3361c27a6d53afbd2)
#         ;
#
#
#
#
#             var marker_1504128687071a8bb3a26a6cf82b5294 = L.marker(
#                 [41.4036, 2.1606],
#                 {}
#             ).addTo(map_7b6f6e2f658f73b0b963e82c57f753cd);
#
#
#         var popup_782d94e8f59b67305217d32dbbe831c5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1abc55fe565869c159ee1417fb0c47f2 = $(`&lt;div id=&quot;html_1abc55fe565869c159ee1417fb0c47f2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Park Güell (Barcelona)&lt;/div&gt;`)[0];
#                 popup_782d94e8f59b67305217d32dbbe831c5.setContent(html_1abc55fe565869c159ee1417fb0c47f2);
#
#
#
#         marker_1504128687071a8bb3a26a6cf82b5294.bindPopup(popup_782d94e8f59b67305217d32dbbe831c5)
#         ;
#
#
#
#
#             var marker_565d7a4111e7f9a7ba163f82f4e54cc5 = L.marker(
#                 [43.2609, -2.9257],
#                 {}
#             ).addTo(map_7b6f6e2f658f73b0b963e82c57f753cd);
#
#
#         var popup_4c7b7b8c04cacef4ab8d7f86830f4707 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5936cb877f6a384721856fe75303d824 = $(`&lt;div id=&quot;html_5936cb877f6a384721856fe75303d824&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Guggenheim Museum Bilbao (Bilbao)&lt;/div&gt;`)[0];
#                 popup_4c7b7b8c04cacef4ab8d7f86830f4707.setContent(html_5936cb877f6a384721856fe75303d824);
#
#
#
#         marker_565d7a4111e7f9a7ba163f82f4e54cc5.bindPopup(popup_4c7b7b8c04cacef4ab8d7f86830f4707)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfulls

# %% [markdown]
# # <font color='red'> <b>Map of Amazon's Top 5 Selling Countries</b><font color='red'>

# %%
# Convert Amazon sales data to a list
amazon_sales = [
    {"country": "US", "sales_amount": 100000000},
    {"country": "DE", "sales_amount": 50000000},
    {"country": "GB", "sales_amount": 40000000},
    {"country": "JP", "sales_amount": 30000000},
    {"country": "FR", "sales_amount": 20000000},
]

import folium

# Create the world map
world_map = folium.Map(location=[0, 0], zoom_start=2)

# Country coordinates
country_coordinates = {
    "US": [37.0902, -95.7129],
    "DE": [51.1657, 10.4515],
    "GB": [55.3781, -3.4360],
    "JP": [36.2048, 138.2529],
    "FR": [46.6034, 1.8883]
}

# Find the country with the highest sales
top_selling_country, top_sales_amount = max([(sale["country"], sale["sales_amount"]) for sale in amazon_sales], key=lambda x: x[1])

# Add markers to the map
for sale in amazon_sales:
    if sale["country"] in country_coordinates:
        popup = f"{sale['country']} - Sales Amount: {sale['sales_amount']:,}"
        folium.Marker(location=country_coordinates[sale["country"]], popup=popup).add_to(world_map)

# Highlight the marker of the top selling country in a different color
if top_selling_country in country_coordinates:
    popup = f"**Top Sales:** {top_selling_country} - {top_sales_amount:,}"
    folium.Marker(location=country_coordinates[top_selling_country], popup=popup, icon=folium.Icon(color='red')).add_to(world_map)

# Save the map
#world_map.save("amazon_sales_map.html")

world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_42da33153b17145e00b07e0346838db9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_42da33153b17145e00b07e0346838db9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_42da33153b17145e00b07e0346838db9 = L.map(
#                 &quot;map_42da33153b17145e00b07e0346838db9&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6225b6fc7035890e27d7c6623726fe9d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_6225b6fc7035890e27d7c6623726fe9d.addTo(map_42da33153b17145e00b07e0346838db9);
#
#
#             var marker_52d52b5d00bcd57f2123d964319c265a = L.marker(
#                 [37.0902, -95.7129],
#                 {}
#             ).addTo(map_42da33153b17145e00b07e0346838db9);
#
#
#         var popup_f12493543c4eb3d5c2db62ccc15c6b05 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_55c22c6c456dcc6fa8e2d08cc9746c6b = $(`&lt;div id=&quot;html_55c22c6c456dcc6fa8e2d08cc9746c6b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;US - Sales Amount: 100,000,000&lt;/div&gt;`)[0];
#                 popup_f12493543c4eb3d5c2db62ccc15c6b05.setContent(html_55c22c6c456dcc6fa8e2d08cc9746c6b);
#
#
#
#         marker_52d52b5d00bcd57f2123d964319c265a.bindPopup(popup_f12493543c4eb3d5c2db62ccc15c6b05)
#         ;
#
#
#
#
#             var marker_5d99359959483de408f4242acf5522c9 = L.marker(
#                 [51.1657, 10.4515],
#                 {}
#             ).addTo(map_42da33153b17145e00b07e0346838db9);
#
#
#         var popup_83f39f8272c622172769c4c79db28320 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_04329f7bc3fb22f5aa245b0557aad10d = $(`&lt;div id=&quot;html_04329f7bc3fb22f5aa245b0557aad10d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;DE - Sales Amount: 50,000,000&lt;/div&gt;`)[0];
#                 popup_83f39f8272c622172769c4c79db28320.setContent(html_04329f7bc3fb22f5aa245b0557aad10d);
#
#
#
#         marker_5d99359959483de408f4242acf5522c9.bindPopup(popup_83f39f8272c622172769c4c79db28320)
#         ;
#
#
#
#
#             var marker_0666b481edf6c147f580b15ba98c5fd6 = L.marker(
#                 [55.3781, -3.436],
#                 {}
#             ).addTo(map_42da33153b17145e00b07e0346838db9);
#
#
#         var popup_a69f355edf9a09cef3a8572c26f973d0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e7c8ee4ffef446dd005afca4f4c23cfe = $(`&lt;div id=&quot;html_e7c8ee4ffef446dd005afca4f4c23cfe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;GB - Sales Amount: 40,000,000&lt;/div&gt;`)[0];
#                 popup_a69f355edf9a09cef3a8572c26f973d0.setContent(html_e7c8ee4ffef446dd005afca4f4c23cfe);
#
#
#
#         marker_0666b481edf6c147f580b15ba98c5fd6.bindPopup(popup_a69f355edf9a09cef3a8572c26f973d0)
#         ;
#
#
#
#
#             var marker_b4fd20fc1167bf514186e1869fac8a80 = L.marker(
#                 [36.2048, 138.2529],
#                 {}
#             ).addTo(map_42da33153b17145e00b07e0346838db9);
#
#
#         var popup_5c5184c65d03a8269fe49047892e009e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2ed75deb4aa8212356bb0769fda4cee2 = $(`&lt;div id=&quot;html_2ed75deb4aa8212356bb0769fda4cee2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;JP - Sales Amount: 30,000,000&lt;/div&gt;`)[0];
#                 popup_5c5184c65d03a8269fe49047892e009e.setContent(html_2ed75deb4aa8212356bb0769fda4cee2);
#
#
#
#         marker_b4fd20fc1167bf514186e1869fac8a80.bindPopup(popup_5c5184c65d03a8269fe49047892e009e)
#         ;
#
#
#
#
#             var marker_010994581c9b8c1ba3c192ffb8887345 = L.marker(
#                 [46.6034, 1.8883],
#                 {}
#             ).addTo(map_42da33153b17145e00b07e0346838db9);
#
#
#         var popup_339f4a50d923e3b543bf687cba3dd95d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4e97eef7e3704eda1e3d501aa18d1834 = $(`&lt;div id=&quot;html_4e97eef7e3704eda1e3d501aa18d1834&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;FR - Sales Amount: 20,000,000&lt;/div&gt;`)[0];
#                 popup_339f4a50d923e3b543bf687cba3dd95d.setContent(html_4e97eef7e3704eda1e3d501aa18d1834);
#
#
#
#         marker_010994581c9b8c1ba3c192ffb8887345.bindPopup(popup_339f4a50d923e3b543bf687cba3dd95d)
#         ;
#
#
#
#
#             var marker_52f9a31cab81280e78a6822e4d3dd67d = L.marker(
#                 [37.0902, -95.7129],
#                 {}
#             ).addTo(

# %% [markdown]
# # <font color='red'> <b>The 5 Most Populous Countries by Population Density</b><font color='red'>

# %%
import folium

# Population data
population_data = [
    {"country": "China", "population": 1444215628},
    {"country": "India", "population": 1380004385},
    {"country": "United States", "population": 332975285},
    {"country": "Indonesia", "population": 273523615},
    {"country": "Pakistan", "population": 235309000},
]

# Coordinates of selected countries
country_coordinates = {
    "China": {"latitude": 35.8617, "longitude": 104.1954},
    "India": {"latitude": 20.5937, "longitude": 78.9629},
    "United States": {"latitude": 37.0902, "longitude": -95.7129},
    "Indonesia": {"latitude": -0.7893, "longitude": 113.9213},
    "Pakistan": {"latitude": 30.3753, "longitude": 69.3451}
}

# Create the world map
world_map = folium.Map(location=[0, 0], zoom_start=2)

# Find the most populous country
most_populous_country = max(population_data, key=lambda x: x["population"])

# Add markers to the map
for country_data in population_data:
    country = country_data["country"]
    popup = f"{country} - Population: {country_data['population']:,}"
    color = 'red' if country_data == most_populous_country else 'blue'
    if country in country_coordinates:
        coordinates = country_coordinates[country]
        folium.Marker(location=[coordinates["latitude"], coordinates["longitude"]], popup=popup, icon=folium.Icon(color=color)).add_to(world_map)

# Show map
world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2fbb4e75231cfaec389ea7779f107dd6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2fbb4e75231cfaec389ea7779f107dd6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2fbb4e75231cfaec389ea7779f107dd6 = L.map(
#                 &quot;map_2fbb4e75231cfaec389ea7779f107dd6&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7bdd74f86dff55c73e2665142a47b4ac = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_7bdd74f86dff55c73e2665142a47b4ac.addTo(map_2fbb4e75231cfaec389ea7779f107dd6);
#
#
#             var marker_97618a922cce19b8c7616e40f56f0ba5 = L.marker(
#                 [35.8617, 104.1954],
#                 {}
#             ).addTo(map_2fbb4e75231cfaec389ea7779f107dd6);
#
#
#             var icon_88e30e5e1f0204c8fdd8c8da5df0f5e3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_97618a922cce19b8c7616e40f56f0ba5.setIcon(icon_88e30e5e1f0204c8fdd8c8da5df0f5e3);
#
#
#         var popup_f749a8f9c82c701d3d8f2e1f1e6e28bd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3e0bb139f96847c15310c23ef7ca0ebb = $(`&lt;div id=&quot;html_3e0bb139f96847c15310c23ef7ca0ebb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;China - Population: 1,444,215,628&lt;/div&gt;`)[0];
#                 popup_f749a8f9c82c701d3d8f2e1f1e6e28bd.setContent(html_3e0bb139f96847c15310c23ef7ca0ebb);
#
#
#
#         marker_97618a922cce19b8c7616e40f56f0ba5.bindPopup(popup_f749a8f9c82c701d3d8f2e1f1e6e28bd)
#         ;
#
#
#
#
#             var marker_e3786949c385a0b2a347b9b5ee477c1a = L.marker(
#                 [20.5937, 78.9629],
#                 {}
#             ).addTo(map_2fbb4e75231cfaec389ea7779f107dd6);
#
#
#             var icon_1531f362e4a5fa350c1ee0c34333a9ae = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e3786949c385a0b2a347b9b5ee477c1a.setIcon(icon_1531f362e4a5fa350c1ee0c34333a9ae);
#
#
#         var popup_17d94da130dfc7350afae655b14690f8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d1cd6388cdd4b9feca14850a65edfc5b = $(`&lt;div id=&quot;html_d1cd6388cdd4b9feca14850a65edfc5b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;India - Population: 1,380,004,385&lt;/div&gt;`)[0];
#                 popup_17d94da130dfc7350afae655b14690f8.setContent(html_d1cd6388cdd4b9feca14850a65edfc5b);
#
#
#
#         marker_e3786949c385a0b2a347b9b5ee477c1a.bindPopup(popup_17d94da130dfc7350afae655b14690f8)
#         ;
#
#
#
#
#             var marker_765b2708531964f42a8aa8ca33dcbf20 = L.marker(
#                 [37.0902, -95.7129],
#                 {}
#             ).addTo(map_2fbb4e75231cfaec389ea7779f107dd6);
#
#
#             var icon_83d4cc1687632a20722e83995b226ca4 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_765b2708531964f42a8aa8ca33dcbf20.setIcon(icon_83d4cc1687632a20722e83995b226ca4);
#
#
#         var popup_1c127d1f9eceda2555196433673e5a95 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d8098dbdf5f6ffedecd96fd0d111ef49 = $(`&lt;div id=&quot;html_d8098dbdf5f6ffedecd96fd0d111ef49&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;United States - Population: 332,975,285&lt;/div&gt;`)[0];
#                 popup_1c127d1f9eceda2555196433673e5a95.setContent(html_d8098dbdf5f6ffedecd96fd0d111ef49);
#
#
#
#         marker_765b2708531964f42a8aa8ca33dcbf20.bindPopup(popup_1c127d1f9eceda2555196433673e5a95)
#         ;
#
#
#
#
#             var marker_bef438b172b7c95698bbf55006da2adb = L.marker(
#                 [-0.7893, 113.9213],
#                 {}
#             ).addTo(map_2fbb4e75231cfaec389ea7779f107dd6);
#
#
#             var icon_38f3bded9625b54478b0b5296b3eb703 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColo

# %% [markdown]
# # <p style="background-color:red;font-family:arial;font-size:110%;color:white;text-align:center;border-radius:20px 20px;"><b>Thank you in the hope that it will be useful
# </b></p>
#
# <b>If you want to be the first to be informed about new projects, please do not forget to follow us </b>[Linkedin](https://www.linkedin.com/in/fatma-nur-azman/) | [Kaggle](https://www.kaggle.com/fnurazman) | [Tableau](https://public.tableau.com/app/profile/fatma.nur.azman/vizzes)
