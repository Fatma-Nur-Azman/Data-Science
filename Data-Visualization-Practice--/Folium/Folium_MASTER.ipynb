# %% [markdown]
# # <p style="background-color:red;font-family:arial;font-size:200%;color:white;text-align:center;border-radius:20px 20px;"><b>FOLIUM</b></p>Animate Maps with Folium: A Powerful Way to Visualize Your Data
# ![](https://media2.giphy.com/media/v1.Y2lkPTc5MGI3NjExZGZlcWkzN2Y5M2MxNjN4MWxyeTE1endkZnp5MWptajIzdXkwOHBxNCZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/UDclWKlmfmq7twI3iJ/giphy.gif)
#
# <b>If you want to be the first to be informed about new projects, please do not forget to follow us - by Fatma Nur AZMAN</b>[Linkedin](https://www.linkedin.com/in/fatma-nur-azman/) | [Kaggle](https://www.kaggle.com/fnurazman) | [Tableau](https://public.tableau.com/app/profile/fatma.nur.azman/vizzes)

# %% [markdown]
# # <font color='red'> <b> Why Folium</b><font color='red'>

# %% [markdown]
# Folium is a map visualization library developed for the Python programming language. It leverages the mapping visualization functionality using the JavaScript-based Leaflet.js library in the background. With this library, we can easily process map data and create interactive maps

# %% [markdown]
# One interesting thing about Folium maps is that they're interactive. This means that even if you set a specific zoom level at the beginning, you can zoom in on any area you're interested in to see it more clearly.

# %% [markdown]
# # <font color='red'> <b>Install & Import & Save</b><font color='red'>

# %%
#conda install -c conda-forge folium
# !pip install folium

# %%
# pip install folium --upgrade

# %%
#This command installs the Geopy library, which is used for geocoding (finding the latitude and longitude of addresses) 
# pip install geopy

# %%
import folium # Import Folium libraries

# %%
# mapname.save("mapname.html") # htm save

# %% [markdown]
# # <font color='red'> <b>Finding Location</b><font color='red'>

# %% [markdown]
# https://www.latlong.net/

# %% [markdown]
# # <font color='red'> <b>Creating a Map</b><font color='red'>

# %%
folium.Map(location=[41.0082, 28.9784])
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_81d33ca43293e7e93d6a24d93920f4f2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_81d33ca43293e7e93d6a24d93920f4f2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_81d33ca43293e7e93d6a24d93920f4f2 = L.map(
#                 &quot;map_81d33ca43293e7e93d6a24d93920f4f2&quot;,
#                 {
#                     center: [41.0082, 28.9784],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4ec2f083ecbcc54f52f0b937407e0ada = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_4ec2f083ecbcc54f52f0b937407e0ada.addTo(map_81d33ca43293e7e93d6a24d93920f4f2);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Import Folium libraries
import folium
# Create a map
ist_map = folium.Map(location=[41.0082, 28.9784], zoom_start=11)
# zoom start The higher the number, the closer you get to the center.

#If you select a high number, you can see streets and alleys near your location in detail.

#If you select 1, you will see the world map with your location in the center.

# ist_map.save("ist_map.html") # puts a link to the location of the project in html

# Show Map
ist_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_97a59bb61bf28f5f947ffd698da9a36d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_97a59bb61bf28f5f947ffd698da9a36d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_97a59bb61bf28f5f947ffd698da9a36d = L.map(
#                 &quot;map_97a59bb61bf28f5f947ffd698da9a36d&quot;,
#                 {
#                     center: [41.0082, 28.9784],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_39e144283898e4c8fb417ae073626229 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_39e144283898e4c8fb417ae073626229.addTo(map_97a59bb61bf28f5f947ffd698da9a36d);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# - location: The field where the coordinates of the marker are specified.
#
# - popup: Description to be shown when clicking on the marker.
#
# - tooltip: Description to be shown when hovering over the marker.
#
# - icon: The icon to represent the marker.
#
# - color: The color of the icon.
#
# - You can use different icons with prefix='fa'.

# %%
# Import Folium libraries
import folium

# Adjust the coordinates of Paris
paris_coordinate = (48.8566, 2.3522)

# Create a Map
paris_map = folium.Map(location=paris_coordinate, zoom_start=11)

# Add markers to the Eiffel Tower
folium.Marker(location=(48.8584, 2.3240),
              popup='Eyfel Kulesi',
              icon=folium.Icon(color='red')).add_to(paris_map)

# Add markers to other tourist attractions
tourist_places = {
    "Louvre Müzesi": (48.8629, 2.3358),
    "Notre Dame Katedrali": (48.8651, 2.3450),
    "Zafer Takı": (48.8736, 2.2762),
    "Montmartre Tepesi": (48.8844, 2.3423),
    "Sacré-Cœur Bazilikası": (48.8860, 2.3419),
}

for ad, coordinate in tourist_places.items():
    folium.Marker(location=coordinate, popup=ad).add_to(paris_map)

# puts a link to the location of the project in html
# paris_haritasi.save("paris_haritasi.html")
# Show Map
paris_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b73d5a898f296c1ad47ff88d4c58bd81 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b73d5a898f296c1ad47ff88d4c58bd81&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b73d5a898f296c1ad47ff88d4c58bd81 = L.map(
#                 &quot;map_b73d5a898f296c1ad47ff88d4c58bd81&quot;,
#                 {
#                     center: [48.8566, 2.3522],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d2983549b2c62c887a72e3e6a046edc9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_d2983549b2c62c887a72e3e6a046edc9.addTo(map_b73d5a898f296c1ad47ff88d4c58bd81);
#
#
#             var marker_7d27748a6834fccc37f6a80716678406 = L.marker(
#                 [48.8584, 2.324],
#                 {}
#             ).addTo(map_b73d5a898f296c1ad47ff88d4c58bd81);
#
#
#             var icon_50a7da321ca60e7f47aa5361946e1de6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7d27748a6834fccc37f6a80716678406.setIcon(icon_50a7da321ca60e7f47aa5361946e1de6);
#
#
#         var popup_3605e0b52cffec0aa6708125b6d43a32 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7b4da97939a65dba88e2ef314affb936 = $(`&lt;div id=&quot;html_7b4da97939a65dba88e2ef314affb936&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Eyfel Kulesi&lt;/div&gt;`)[0];
#                 popup_3605e0b52cffec0aa6708125b6d43a32.setContent(html_7b4da97939a65dba88e2ef314affb936);
#
#
#
#         marker_7d27748a6834fccc37f6a80716678406.bindPopup(popup_3605e0b52cffec0aa6708125b6d43a32)
#         ;
#
#
#
#
#             var marker_a46e69e6efcb4f4a0a811dc430170ac1 = L.marker(
#                 [48.8629, 2.3358],
#                 {}
#             ).addTo(map_b73d5a898f296c1ad47ff88d4c58bd81);
#
#
#         var popup_bada6322dc71ae6c654afdf7f76bea6b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a43899562a7431e7163d2319b3e1b894 = $(`&lt;div id=&quot;html_a43899562a7431e7163d2319b3e1b894&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Louvre Müzesi&lt;/div&gt;`)[0];
#                 popup_bada6322dc71ae6c654afdf7f76bea6b.setContent(html_a43899562a7431e7163d2319b3e1b894);
#
#
#
#         marker_a46e69e6efcb4f4a0a811dc430170ac1.bindPopup(popup_bada6322dc71ae6c654afdf7f76bea6b)
#         ;
#
#
#
#
#             var marker_01a55ed565887b243e6bf5ea54846f80 = L.marker(
#                 [48.8651, 2.345],
#                 {}
#             ).addTo(map_b73d5a898f296c1ad47ff88d4c58bd81);
#
#
#         var popup_8ebdae15ed013f713bf68a4278e794c5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b6984e4115f9615615bf0c0576deb3ff = $(`&lt;div id=&quot;html_b6984e4115f9615615bf0c0576deb3ff&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Notre Dame Katedrali&lt;/div&gt;`)[0];
#                 popup_8ebdae15ed013f713bf68a4278e794c5.setContent(html_b6984e4115f9615615bf0c0576deb3ff);
#
#
#
#         marker_01a55ed565887b243e6bf5ea54846f80.bindPopup(popup_8ebdae15ed013f713bf68a4278e794c5)
#         ;
#
#
#
#
#             var marker_c3129bdd63de867f000d706e52926310 = L.marker(
#                 [48.8736, 2.2762],
#                 {}
#             ).addTo(map_b73d5a898f296c1ad47ff88d4c58bd81);
#
#
#         var popup_1bfe139925210aa4bdb6e4408e2cc780 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_122ac93b5ffdabb3e454afee316802e6 = $(`&lt;div id=&quot;html_122ac93b5ffdabb3e454afee316802e6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Zafer Takı&lt;/div&gt;`)[0];
#                 popup_1bfe139925210aa4bdb6e4408e2cc780.setContent(html_122ac93b5ffdabb3e454afee316802e6);
#
#
#
#         marker_c3129bdd63de867f000d706e52926310.bindPopup(popup_1bfe139925210aa4bdb6e4408e2cc780)
#         ;
#
#
#
#
#             var marker_12c8f800b8f78593954bf44cb89a046c = L.marker(
#                 [48.8844, 2.3423],
#                 {}
#             ).addTo(map_b73d5a898f296c1ad47ff88d4c58bd81);
#
#
#         var popup_b92b300b256fdb7d93d3718de32d8fd6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4546c456fa02848cb36e9c3c6c07b5ae = $(`&lt;div id=&quot;html_4546c456fa02848cb36e9c3c6c07b5ae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Montmartre Tepesi&lt;/div&gt;`)[0];
#                 popup_b92b300b

# %% [markdown]
# Some values the tiles parameter can take are:
#
# CartoDB Positron: This offers a modern and minimalist map style. It has grey tones, white labels, and dark borders, making it good for data visualizations.
#
# Stamen Terrain: This is a colorful map style showing natural landforms and topographic features. It highlights mountains, hills, bodies of water, and green areas.
#
# Stamen Watercolor: This has a hand-drawn style in watercolors. It highlights natural features like water, land, and vegetation, with a high artistic design.
#
# Stamen Toner: This is a black and white map style. It emphasizes details like roads, borders, and labels. It is ideal for data visualizations.
#
# CartoDB Dark Matter: This has a black background with white labels, offering a minimalist map style. It is suitable for scientific maps, visualizations, and analyses.

# %%
# Import Folium libraries
import folium

m = folium.Map(location=[45.523, -122.675], width=750, height=500)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6f93aee78dd77ae7dd19b096dc3faa90 {
#                     position: relative;
#                     width: 750.0px;
#                     height: 500.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6f93aee78dd77ae7dd19b096dc3faa90&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6f93aee78dd77ae7dd19b096dc3faa90 = L.map(
#                 &quot;map_6f93aee78dd77ae7dd19b096dc3faa90&quot;,
#                 {
#                     center: [45.523, -122.675],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_480b9fb439da3e1d8b8910d5671f45e9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_480b9fb439da3e1d8b8910d5671f45e9.addTo(map_6f93aee78dd77ae7dd19b096dc3faa90);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Import Folium libraries
import folium

m = folium.Map(location=[45.523, -122.675], tiles="cartodb positron")
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ffb81a6dd4ce20669bd091319dd0cb14 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ffb81a6dd4ce20669bd091319dd0cb14&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ffb81a6dd4ce20669bd091319dd0cb14 = L.map(
#                 &quot;map_ffb81a6dd4ce20669bd091319dd0cb14&quot;,
#                 {
#                     center: [45.523, -122.675],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_81ff0d31ed321f655e4e847ab2aded49 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_81ff0d31ed321f655e4e847ab2aded49.addTo(map_ffb81a6dd4ce20669bd091319dd0cb14);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Import Folium libraries
import folium

m = folium.Map(location=[45.523, -122.675], tiles="CartoDB Voyager")
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_97bf7791bf9cce02b69631db88d6091d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_97bf7791bf9cce02b69631db88d6091d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_97bf7791bf9cce02b69631db88d6091d = L.map(
#                 &quot;map_97bf7791bf9cce02b69631db88d6091d&quot;,
#                 {
#                     center: [45.523, -122.675],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5d75fce6a7228c2e177eb0132d59c09f = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/rastertiles/voyager/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_5d75fce6a7228c2e177eb0132d59c09f.addTo(map_97bf7791bf9cce02b69631db88d6091d);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Import Folium libraries
import folium

folium.Map(location=[41.0082, 28.9784], tiles="Cartodb dark_matter")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_127b8b8bd952c3c32664c37dc8344d44 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_127b8b8bd952c3c32664c37dc8344d44&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_127b8b8bd952c3c32664c37dc8344d44 = L.map(
#                 &quot;map_127b8b8bd952c3c32664c37dc8344d44&quot;,
#                 {
#                     center: [41.0082, 28.9784],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ccecb584a3fa52710554bbdd74c65eac = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/dark_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_ccecb584a3fa52710554bbdd74c65eac.addTo(map_127b8b8bd952c3c32664c37dc8344d44);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ##  Adding Pop ups

# %%
# Import Folium libraries
import folium
# Create a map
ist_map = folium.Map(location=[41.0082, 28.9784], zoom_start=11)
# zoom start The higher the number, the closer you are to the center.
#If you choose a high number, you can see streets and roads near your location in detail.
#If you choose 1, you will see a world map with your location in the center.

# Add markers
folium.Marker(location=[41.0122, 28.9764],
              popup='Sultanahmet Camii').add_to(ist_map)
folium.Marker(location=[41.0554, 28.9940],
              popup='Galata Kulesi').add_to(ist_map)
folium.Marker(location=[41.0339, 28.9774], popup='Kapalıçarşı').add_to(ist_map)

# puts a link to the location of the project in html
# ist_map.save("ist_map.html")
# Show Map
ist_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_10aca87ec3f472f4a1732984093359e0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_10aca87ec3f472f4a1732984093359e0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_10aca87ec3f472f4a1732984093359e0 = L.map(
#                 &quot;map_10aca87ec3f472f4a1732984093359e0&quot;,
#                 {
#                     center: [41.0082, 28.9784],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d1f9926a4641fb983c682c5fe3401f61 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_d1f9926a4641fb983c682c5fe3401f61.addTo(map_10aca87ec3f472f4a1732984093359e0);
#
#
#             var marker_31ab00c7c7cbbde6a9007ac567886497 = L.marker(
#                 [41.0122, 28.9764],
#                 {}
#             ).addTo(map_10aca87ec3f472f4a1732984093359e0);
#
#
#         var popup_7c53260466b752ed6df1fd08db1037ea = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9c26903bb27c546bcb1800f1c84ad0db = $(`&lt;div id=&quot;html_9c26903bb27c546bcb1800f1c84ad0db&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sultanahmet Camii&lt;/div&gt;`)[0];
#                 popup_7c53260466b752ed6df1fd08db1037ea.setContent(html_9c26903bb27c546bcb1800f1c84ad0db);
#
#
#
#         marker_31ab00c7c7cbbde6a9007ac567886497.bindPopup(popup_7c53260466b752ed6df1fd08db1037ea)
#         ;
#
#
#
#
#             var marker_c0425284687afdb6db14097a3059a18c = L.marker(
#                 [41.0554, 28.994],
#                 {}
#             ).addTo(map_10aca87ec3f472f4a1732984093359e0);
#
#
#         var popup_0aa1139a397b5f3d141ad11dbc3017fa = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f560b1cb0d2e425c9d8679b018a585a6 = $(`&lt;div id=&quot;html_f560b1cb0d2e425c9d8679b018a585a6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Galata Kulesi&lt;/div&gt;`)[0];
#                 popup_0aa1139a397b5f3d141ad11dbc3017fa.setContent(html_f560b1cb0d2e425c9d8679b018a585a6);
#
#
#
#         marker_c0425284687afdb6db14097a3059a18c.bindPopup(popup_0aa1139a397b5f3d141ad11dbc3017fa)
#         ;
#
#
#
#
#             var marker_56bf7219b9f399f406d97795a80a493c = L.marker(
#                 [41.0339, 28.9774],
#                 {}
#             ).addTo(map_10aca87ec3f472f4a1732984093359e0);
#
#
#         var popup_b3665f2281839b4034652c2076502043 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_205e8beae9401a575e3e5db3bfdb8aad = $(`&lt;div id=&quot;html_205e8beae9401a575e3e5db3bfdb8aad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Kapalıçarşı&lt;/div&gt;`)[0];
#                 popup_b3665f2281839b4034652c2076502043.setContent(html_205e8beae9401a575e3e5db3bfdb8aad);
#
#
#
#         marker_56bf7219b9f399f406d97795a80a493c.bindPopup(popup_b3665f2281839b4034652c2076502043)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Adding icons

# %%
# Import Folium libraries
import folium
## Hagia Sophia coordinates
ayasofya_coordinat = [41.0084, 28.9774]

# Galata Kulesi  coordinates
galata_coordinat = [41.0257, 28.9744]

# Create a Map
ist_map = folium.Map(location=[41.0082, 28.9784], zoom_start=12)

# Add markers to the Ayasofya
ayasofya_marker = folium.Marker(location=ayasofya_coordinat,
                                popup="Ayasofya",
                                tooltip="Ayasofya Camii",
                                icon=folium.Icon(prefix='fa',
                                                 icon='fa-mosque',
                                                 color='green'))

# Add markers to the Galata Kulesi
galata_marker = folium.Marker(location=galata_coordinat,
                              popup="Galata Kulesi",
                              tooltip="Galata Kulesi",
                              icon=folium.Icon(prefix='fa',
                                               icon='fa-fort-awesome',
                                               color='blue'))

# Add markers to other tourist attractions
ayasofya_marker.add_to(ist_map)
galata_marker.add_to(ist_map)

# Show a Map
ist_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e122e0d90e983904f21a5c87323f2a38 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e122e0d90e983904f21a5c87323f2a38&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e122e0d90e983904f21a5c87323f2a38 = L.map(
#                 &quot;map_e122e0d90e983904f21a5c87323f2a38&quot;,
#                 {
#                     center: [41.0082, 28.9784],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a6245882b10575bbd2d96c63a5a0f879 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_a6245882b10575bbd2d96c63a5a0f879.addTo(map_e122e0d90e983904f21a5c87323f2a38);
#
#
#             var marker_72927aab770e89cace2888bdeff8b8da = L.marker(
#                 [41.0084, 28.9774],
#                 {}
#             ).addTo(map_e122e0d90e983904f21a5c87323f2a38);
#
#
#             var icon_3fa1e93f6acdab820e81b40034c9914f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-mosque&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_72927aab770e89cace2888bdeff8b8da.setIcon(icon_3fa1e93f6acdab820e81b40034c9914f);
#
#
#         var popup_5c4a6ad0b69cbe6a563683d25f4378e0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_85c4bdbbab10a30a690c12bbea871993 = $(`&lt;div id=&quot;html_85c4bdbbab10a30a690c12bbea871993&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Ayasofya&lt;/div&gt;`)[0];
#                 popup_5c4a6ad0b69cbe6a563683d25f4378e0.setContent(html_85c4bdbbab10a30a690c12bbea871993);
#
#
#
#         marker_72927aab770e89cace2888bdeff8b8da.bindPopup(popup_5c4a6ad0b69cbe6a563683d25f4378e0)
#         ;
#
#
#
#
#             marker_72927aab770e89cace2888bdeff8b8da.bindTooltip(
#                 `&lt;div&gt;
#                      Ayasofya Camii
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_3d184624126e6881ed156d8d5feae458 = L.marker(
#                 [41.0257, 28.9744],
#                 {}
#             ).addTo(map_e122e0d90e983904f21a5c87323f2a38);
#
#
#             var icon_2ae2c5c514d02ed44b325b43ba06d0e7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-fort-awesome&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_3d184624126e6881ed156d8d5feae458.setIcon(icon_2ae2c5c514d02ed44b325b43ba06d0e7);
#
#
#         var popup_8863f9bec58d0e0b0d2858995851d70e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_531acc9363cc1c990e06c2e3ad3c3888 = $(`&lt;div id=&quot;html_531acc9363cc1c990e06c2e3ad3c3888&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Galata Kulesi&lt;/div&gt;`)[0];
#                 popup_8863f9bec58d0e0b0d2858995851d70e.setContent(html_531acc9363cc1c990e06c2e3ad3c3888);
#
#
#
#         marker_3d184624126e6881ed156d8d5feae458.bindPopup(popup_8863f9bec58d0e0b0d2858995851d70e)
#         ;
#
#
#
#
#             marker_3d184624126e6881ed156d8d5feae458.bindTooltip(
#                 `&lt;div&gt;
#                      Galata Kulesi
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Adding Tooltip

# %%
# Locations of historical monuments in Istanbul
istanbul_tarihi_eserler = {
    "Ayasofya": [41.0084, 28.9799],
    "Topkapı Sarayı": [41.0115, 28.9833],
    "Süleymaniye Camii": [41.0115, 28.9584],
    "Yerebatan Sarnıcı": [41.0085, 28.9799],
    "Galata Kulesi": [41.0257, 28.9744]
}

import folium

# Create a map centered at the coordinates [6.4516082, 3.4070867] with a zoom level of 12
m = folium.Map(location=[6.4516082, 3.4070867], zoom_start=12)

# Define a tooltip message
tooltip = "Click me tooltip"

# Add a marker to the map
folium.Marker(
    [6.4516082, 3.4070867],  # Coordinates of the marker
    popup='<strong>Location one</strong>',  # Text displayed when the marker is clicked
    tooltip=tooltip  # Tooltip message displayed when hovering over the marker
).add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9221b14b68436d0a50b57a987a2f27ee {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9221b14b68436d0a50b57a987a2f27ee&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9221b14b68436d0a50b57a987a2f27ee = L.map(
#                 &quot;map_9221b14b68436d0a50b57a987a2f27ee&quot;,
#                 {
#                     center: [6.4516082, 3.4070867],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_88407e22f5dab3261769c670ea288965 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_88407e22f5dab3261769c670ea288965.addTo(map_9221b14b68436d0a50b57a987a2f27ee);
#
#
#             var marker_0685f0bd915a53c6138614824d94ef34 = L.marker(
#                 [6.4516082, 3.4070867],
#                 {}
#             ).addTo(map_9221b14b68436d0a50b57a987a2f27ee);
#
#
#         var popup_de0ed942a905148f49a4bdd727a01610 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9ff51275ddc33cbcb1a435e2cdec95f6 = $(`&lt;div id=&quot;html_9ff51275ddc33cbcb1a435e2cdec95f6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;Location one&lt;/strong&gt;&lt;/div&gt;`)[0];
#                 popup_de0ed942a905148f49a4bdd727a01610.setContent(html_9ff51275ddc33cbcb1a435e2cdec95f6);
#
#
#
#         marker_0685f0bd915a53c6138614824d94ef34.bindPopup(popup_de0ed942a905148f49a4bdd727a01610)
#         ;
#
#
#
#
#             marker_0685f0bd915a53c6138614824d94ef34.bindTooltip(
#                 `&lt;div&gt;
#                      Click me tooltip
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Creating Location Markers

# %%
# Import Folium libraries
import folium
# Create a Map
ist_map = folium.Map(location=[41.0082, 28.9784], zoom_start=11)

# Add markers
folium.Marker(location=[41.0122, 28.9764],
              popup='Sultanahmet Camii').add_to(ist_map)
folium.Marker(location=[41.0554, 28.9940],
              popup='Galata Kulesi').add_to(ist_map)
folium.Marker(location=[41.0339, 28.9774], popup='Kapalıçarşı').add_to(ist_map)

# Show Map
ist_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9947a4ad8bacf7d3d6cb08ad20e0992e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9947a4ad8bacf7d3d6cb08ad20e0992e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9947a4ad8bacf7d3d6cb08ad20e0992e = L.map(
#                 &quot;map_9947a4ad8bacf7d3d6cb08ad20e0992e&quot;,
#                 {
#                     center: [41.0082, 28.9784],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_792de02bf9ff04e5e06b9192747a78c7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_792de02bf9ff04e5e06b9192747a78c7.addTo(map_9947a4ad8bacf7d3d6cb08ad20e0992e);
#
#
#             var marker_0efac13c259f5987a0b71ee39b077ab9 = L.marker(
#                 [41.0122, 28.9764],
#                 {}
#             ).addTo(map_9947a4ad8bacf7d3d6cb08ad20e0992e);
#
#
#         var popup_7343997455ba66d90badd90cba0434e3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_231ee83e4b20b5f7bd4dcdfadfab5ed8 = $(`&lt;div id=&quot;html_231ee83e4b20b5f7bd4dcdfadfab5ed8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sultanahmet Camii&lt;/div&gt;`)[0];
#                 popup_7343997455ba66d90badd90cba0434e3.setContent(html_231ee83e4b20b5f7bd4dcdfadfab5ed8);
#
#
#
#         marker_0efac13c259f5987a0b71ee39b077ab9.bindPopup(popup_7343997455ba66d90badd90cba0434e3)
#         ;
#
#
#
#
#             var marker_1b3ba6f855fad655177a542a868db94b = L.marker(
#                 [41.0554, 28.994],
#                 {}
#             ).addTo(map_9947a4ad8bacf7d3d6cb08ad20e0992e);
#
#
#         var popup_dcac2f72159681c1cc34f2b8e0fd319d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_41a1b5138de963a265b63d05a77bf544 = $(`&lt;div id=&quot;html_41a1b5138de963a265b63d05a77bf544&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Galata Kulesi&lt;/div&gt;`)[0];
#                 popup_dcac2f72159681c1cc34f2b8e0fd319d.setContent(html_41a1b5138de963a265b63d05a77bf544);
#
#
#
#         marker_1b3ba6f855fad655177a542a868db94b.bindPopup(popup_dcac2f72159681c1cc34f2b8e0fd319d)
#         ;
#
#
#
#
#             var marker_649ffb1e019b69d16a073bb30404fa95 = L.marker(
#                 [41.0339, 28.9774],
#                 {}
#             ).addTo(map_9947a4ad8bacf7d3d6cb08ad20e0992e);
#
#
#         var popup_a9da1ec3517a3c064678895adff93e62 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bbf8ae50dd160f802c19e5767005402a = $(`&lt;div id=&quot;html_bbf8ae50dd160f802c19e5767005402a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Kapalıçarşı&lt;/div&gt;`)[0];
#                 popup_a9da1ec3517a3c064678895adff93e62.setContent(html_bbf8ae50dd160f802c19e5767005402a);
#
#
#
#         marker_649ffb1e019b69d16a073bb30404fa95.bindPopup(popup_a9da1ec3517a3c064678895adff93e62)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Import Folium libraries
import folium
# Create a Map
ist_map = folium.Map(
    location=[41.0082, 28.9784], zoom_start=11
)

# Add markers
folium.Circle(location=[41.0122, 28.9764], radius=500, color="red",
              fill=False).add_to(ist_map)

folium.CircleMarker(location=[41.0554, 28.9940],
                    radius=10,
                    color="blue",
                    fill=True,
                    fill_color="blue").add_to(ist_map)

folium.Marker(location=[41.0339, 28.9774], popup='Kapalıçarşı').add_to(ist_map)

# Show Map
ist_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dba0b7fcd445920efad758b1b01e4263 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dba0b7fcd445920efad758b1b01e4263&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dba0b7fcd445920efad758b1b01e4263 = L.map(
#                 &quot;map_dba0b7fcd445920efad758b1b01e4263&quot;,
#                 {
#                     center: [41.0082, 28.9784],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b296717e1655e13e8c358e53b778ae3c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_b296717e1655e13e8c358e53b778ae3c.addTo(map_dba0b7fcd445920efad758b1b01e4263);
#
#
#             var circle_580b021b291568f686e49cea9c99032e = L.circle(
#                 [41.0122, 28.9764],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 500, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_dba0b7fcd445920efad758b1b01e4263);
#
#
#             var circle_marker_240732a774f381875d3ded7b96097c19 = L.circleMarker(
#                 [41.0554, 28.994],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_dba0b7fcd445920efad758b1b01e4263);
#
#
#             var marker_864e7d7440fee804464eecbc1ded035e = L.marker(
#                 [41.0339, 28.9774],
#                 {}
#             ).addTo(map_dba0b7fcd445920efad758b1b01e4263);
#
#
#         var popup_e91aa38ea30c3c8d6851b5bc5dddb9f8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6b1ff841f20cb6b8bb6653385d34665f = $(`&lt;div id=&quot;html_6b1ff841f20cb6b8bb6653385d34665f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Kapalıçarşı&lt;/div&gt;`)[0];
#                 popup_e91aa38ea30c3c8d6851b5bc5dddb9f8.setContent(html_6b1ff841f20cb6b8bb6653385d34665f);
#
#
#
#         marker_864e7d7440fee804464eecbc1ded035e.bindPopup(popup_e91aa38ea30c3c8d6851b5bc5dddb9f8)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Minimap

# %% [markdown]
# Minimap in the Folium library shows a small map in a corner. It helps users see the whole map and their location

# %%
# Import Folium libraries
import folium
import folium.plugins

m = folium.Map(location=[41.0151, 28.9792], zoom_start=10)
# Add Minimap
minimap = folium.plugins.MiniMap()
m.add_child(minimap)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_34b3ce46c65c8409329b77cdbb92942f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_34b3ce46c65c8409329b77cdbb92942f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_34b3ce46c65c8409329b77cdbb92942f = L.map(
#                 &quot;map_34b3ce46c65c8409329b77cdbb92942f&quot;,
#                 {
#                     center: [41.0151, 28.9792],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cb6e16c823c16bf5b99b5bb818b4bf91 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_cb6e16c823c16bf5b99b5bb818b4bf91.addTo(map_34b3ce46c65c8409329b77cdbb92942f);
#
#
#             var tile_layer_768274403c81a9d39791ebadf7025a56 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#             var mini_map_ed805b7ca8562cde3eb7bd6ed2429dca = new L.Control.MiniMap(
#                 tile_layer_768274403c81a9d39791ebadf7025a56,
#                 {&quot;autoToggleDisplay&quot;: false, &quot;centerFixed&quot;: false, &quot;collapsedHeight&quot;: 25, &quot;collapsedWidth&quot;: 25, &quot;height&quot;: 150, &quot;minimized&quot;: false, &quot;position&quot;: &quot;bottomright&quot;, &quot;toggleDisplay&quot;: false, &quot;width&quot;: 150, &quot;zoomAnimation&quot;: false, &quot;zoomLevelOffset&quot;: -5}
#             );
#             map_34b3ce46c65c8409329b77cdbb92942f.addControl(mini_map_ed805b7ca8562cde3eb7bd6ed2429dca);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Displaying Line Between 2 Distances

# %%
# Import the required Python libraries
import folium  # This library helps create interactive maps
from geopy.distance import geodesic  # This library calculates geographical distances

# Create a folium map centered around the given latitude and longitude with a certain zoom level
m = folium.Map([31.335432273991238, 75.53764505992153], zoom_start=6)

# Add a marker to the map with a specific location and a popup message
m.add_child(folium.Marker(location=[31.333, 75.537], popup="First Marker"))

# Create a feature group to organize map features
fg = folium.FeatureGroup(name="My map")

# Add a marker with a green color icon to the feature group
fg.add_child(
    folium.Marker(location=[32.00, 75.00],
                  popup="2nd",
                  icon=folium.Icon(color="green"))
)

# Add the feature group to the map
m.add_child(fg)

# Calculate the distance between two points in miles and convert it to kilometers
distance_miles = geodesic([31.333, 75.537], [32.00, 75.00]).miles
distance_km = distance_miles * 1.60934

# Create a polygon between two points on the map and display the calculated distance as a popup
folium.Polygon(locations=[[31.333, 75.537], [32.00, 75.00]],
               popup=f"The distance is approximately {distance_km:.2f} kilometers.",
               color='blue').add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_29f4faee925d8e97ae3ac2349bbab20c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_29f4faee925d8e97ae3ac2349bbab20c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_29f4faee925d8e97ae3ac2349bbab20c = L.map(
#                 &quot;map_29f4faee925d8e97ae3ac2349bbab20c&quot;,
#                 {
#                     center: [31.335432273991238, 75.53764505992153],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c6f5f2720279e6a41fa50942959c372b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c6f5f2720279e6a41fa50942959c372b.addTo(map_29f4faee925d8e97ae3ac2349bbab20c);
#
#
#             var marker_ba3a667a299decd70ddef8d60f12678f = L.marker(
#                 [31.333, 75.537],
#                 {}
#             ).addTo(map_29f4faee925d8e97ae3ac2349bbab20c);
#
#
#         var popup_bb30b64c05783c5836b9a6280e146e47 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b2afe7c4fc575ddba29f209a55b01409 = $(`&lt;div id=&quot;html_b2afe7c4fc575ddba29f209a55b01409&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;First Marker&lt;/div&gt;`)[0];
#                 popup_bb30b64c05783c5836b9a6280e146e47.setContent(html_b2afe7c4fc575ddba29f209a55b01409);
#
#
#
#         marker_ba3a667a299decd70ddef8d60f12678f.bindPopup(popup_bb30b64c05783c5836b9a6280e146e47)
#         ;
#
#
#
#
#             var feature_group_ba0f115964efa13badac3e96e8a89815 = L.featureGroup(
#                 {}
#             );
#
#
#             var marker_7bb35fd03a77c851c46c50c5d12af8a1 = L.marker(
#                 [32.0, 75.0],
#                 {}
#             ).addTo(feature_group_ba0f115964efa13badac3e96e8a89815);
#
#
#             var icon_f57f04fa5b93d2fcf14a17746a24a0d8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7bb35fd03a77c851c46c50c5d12af8a1.setIcon(icon_f57f04fa5b93d2fcf14a17746a24a0d8);
#
#
#         var popup_e66bc2b5cc791d60b4c82ff2fa4312aa = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_82c2dcd50bfd6732838e6adc1702f994 = $(`&lt;div id=&quot;html_82c2dcd50bfd6732838e6adc1702f994&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;2nd&lt;/div&gt;`)[0];
#                 popup_e66bc2b5cc791d60b4c82ff2fa4312aa.setContent(html_82c2dcd50bfd6732838e6adc1702f994);
#
#
#
#         marker_7bb35fd03a77c851c46c50c5d12af8a1.bindPopup(popup_e66bc2b5cc791d60b4c82ff2fa4312aa)
#         ;
#
#
#
#
#             feature_group_ba0f115964efa13badac3e96e8a89815.addTo(map_29f4faee925d8e97ae3ac2349bbab20c);
#
#
#             var polygon_69f7f2c32ec8afe99681abf1bd8c2cbc = L.polygon(
#                 [[31.333, 75.537], [32.0, 75.0]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_29f4faee925d8e97ae3ac2349bbab20c);
#
#
#         var popup_40fcb0725c83918daacb89bddd597e16 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_99f0efc6afa6c6b0a3a575dd6c7d7537 = $(`&lt;div id=&quot;html_99f0efc6afa6c6b0a3a575dd6c7d7537&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;The distance is approximately 89.79 kilometers.&lt;/div&gt;`)[0];
#                 popup_40fcb0725c83918daacb89bddd597e16.setContent(html_99f0efc6afa6c6b0a3a575dd6c7d7537);
#
#
#
#         polygon_69f7f2c32ec8afe99681abf1bd8c2cbc.bindPopup(popup_40fcb0725c83918daacb89bddd597e16)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Import Folium libraries
import folium
# Create a folium map
m = folium.Map(location=[41.015, 28.979], zoom_start=13)

# Define locations for the route guidance
locations = [
    [41.0054, 28.9767],  # Starting point coordinates
    [41.0257, 28.9744],  # Intermediate point coordinates
    [41.0368, 28.9850]  # Ending point coordinates
]

# Create a PolyLine to display the route guidance
folium.PolyLine(locations=locations, color="red").add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_31f4f195ffa86209e9a3f163d5b7e004 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_31f4f195ffa86209e9a3f163d5b7e004&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_31f4f195ffa86209e9a3f163d5b7e004 = L.map(
#                 &quot;map_31f4f195ffa86209e9a3f163d5b7e004&quot;,
#                 {
#                     center: [41.015, 28.979],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4b93b099b05e7429bee9bb5e2f3e32fd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_4b93b099b05e7429bee9bb5e2f3e32fd.addTo(map_31f4f195ffa86209e9a3f163d5b7e004);
#
#
#             var poly_line_33f00290bfca89cc122e9bb56abca8fb = L.polyline(
#                 [[41.0054, 28.9767], [41.0257, 28.9744], [41.0368, 28.985]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_31f4f195ffa86209e9a3f163d5b7e004);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Measuring Distance Between Locations

# %%
# Import Folium libraries
import folium
from folium.plugins import MeasureControl

# Create the map
istanbul_map = folium.Map(location=[41.015137, 28.979530], zoom_start=12)

# Add the MeasureControl plugin
folium.plugins.MeasureControl(position="topleft", primary_length_unit="kilometers",
                              primary_area_unit="hectares", active_color="red",
                              style={"color":"#ff0000", "linecolor":"red"}).add_to(istanbul_map)

# Display the map
istanbul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_627e4f02d6e2faf1fe5e553f01e277bc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/ljagis/leaflet-measure@2.1.7/dist/leaflet-measure.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/ljagis/leaflet-measure@2.1.7/dist/leaflet-measure.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_627e4f02d6e2faf1fe5e553f01e277bc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_627e4f02d6e2faf1fe5e553f01e277bc = L.map(
#                 &quot;map_627e4f02d6e2faf1fe5e553f01e277bc&quot;,
#                 {
#                     center: [41.015137, 28.97953],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3136a4e5521bd4f2d5b475a1d1dc353c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_3136a4e5521bd4f2d5b475a1d1dc353c.addTo(map_627e4f02d6e2faf1fe5e553f01e277bc);
#
#
#             var measure_control_daf132ff8eced3d463794b54e39c2d7a = new L.Control.Measure(
#                 {&quot;activeColor&quot;: &quot;red&quot;, &quot;position&quot;: &quot;topleft&quot;, &quot;primaryAreaUnit&quot;: &quot;hectares&quot;, &quot;primaryLengthUnit&quot;: &quot;kilometers&quot;, &quot;secondaryAreaUnit&quot;: &quot;acres&quot;, &quot;secondaryLengthUnit&quot;: &quot;miles&quot;, &quot;style&quot;: {&quot;color&quot;: &quot;#ff0000&quot;, &quot;linecolor&quot;: &quot;red&quot;}});
#             map_627e4f02d6e2faf1fe5e553f01e277bc.addControl(measure_control_daf132ff8eced3d463794b54e39c2d7a);
#
#             // Workaround for using this plugin with Leaflet&gt;=1.8.0
#             // https://github.com/ljagis/leaflet-measure/issues/171
#             L.Control.Measure.include({
#                 _setCaptureMarkerIcon: function () {
#                     // disable autopan
#                     this._captureMarker.options.autoPanOnFocus = false;
#                     // default function
#                     this._captureMarker.setIcon(
#                         L.divIcon({
#                             iconSize: this._map.getSize().multiplyBy(2)
#                         })
#                     );
#                 },
#             });
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Grouping Distant Markers

# %%
# Import Python libraries
import folium
from folium.plugins import MarkerCluster

# Create the map
m = folium.Map(location=[41.0082, 28.9784], zoom_start=11)

# Create a MarkerCluster
marker_cluster = MarkerCluster().add_to(m)

# Sample locations
locations = [[41.0122, 28.9764, 'Sultanahmet Mosque'], [41.0554, 28.9940, 'Galata Tower'], [41.0339, 28.9774, 'Grand Bazaar']]

# Create a Marker for each location and add it to the MarkerCluster
for location in locations:
    marker = folium.Marker(location=location[:2], popup=location[2])
    marker.add_to(marker_cluster)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e9d228bab09db786ec099a45cd6a4064 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e9d228bab09db786ec099a45cd6a4064&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e9d228bab09db786ec099a45cd6a4064 = L.map(
#                 &quot;map_e9d228bab09db786ec099a45cd6a4064&quot;,
#                 {
#                     center: [41.0082, 28.9784],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b6a69ff0ce2e21b25519115916e249b0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_b6a69ff0ce2e21b25519115916e249b0.addTo(map_e9d228bab09db786ec099a45cd6a4064);
#
#
#             var marker_cluster_29a526af2a306d12fbf6ecb714d76078 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_114c102f9259d79022de3351fbc78fbd = L.marker(
#                 [41.0122, 28.9764],
#                 {}
#             ).addTo(marker_cluster_29a526af2a306d12fbf6ecb714d76078);
#
#
#         var popup_0381731a5af115d706b76fb33e770b79 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_48abf806ff67cd79a6edf1c6ba866b4a = $(`&lt;div id=&quot;html_48abf806ff67cd79a6edf1c6ba866b4a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sultanahmet Mosque&lt;/div&gt;`)[0];
#                 popup_0381731a5af115d706b76fb33e770b79.setContent(html_48abf806ff67cd79a6edf1c6ba866b4a);
#
#
#
#         marker_114c102f9259d79022de3351fbc78fbd.bindPopup(popup_0381731a5af115d706b76fb33e770b79)
#         ;
#
#
#
#
#             var marker_6a0f8782462d839bde51c4c0e8126c3d = L.marker(
#                 [41.0554, 28.994],
#                 {}
#             ).addTo(marker_cluster_29a526af2a306d12fbf6ecb714d76078);
#
#
#         var popup_519de91e8c9d1bd898e92b0a4bf02860 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_84e832fab610346efabaadbca678b18d = $(`&lt;div id=&quot;html_84e832fab610346efabaadbca678b18d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Galata Tower&lt;/div&gt;`)[0];
#                 popup_519de91e8c9d1bd898e92b0a4bf02860.setContent(html_84e832fab610346efabaadbca678b18d);
#
#
#
#         marker_6a0f8782462d839bde51c4c0e8126c3d.bindPopup(popup_519de91e8c9d1bd898e92b0a4bf02860)
#         ;
#
#
#
#
#             var marker_d1a3f9b5b792d6ffa9b23089f1b198bb = L.marker(
#                 [41.0339, 28.9774],
#                 {}
#             ).addTo(marker_cluster_29a526af2a306d12fbf6ecb714d76078);
#
#
#         var popup_3bb660d732de98fbdeb7a5e08328ad93 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1d316b316c644706d50e9fc26b862952 = $(`&lt;div id=&quot;html_1d316b316c644706d50e9fc26b862952&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Grand Bazaar&lt;/div&gt;`)[0];
#                 popup_3bb660d732de98fbdeb7a5e08328ad93.setContent(html_1d316b316c644706d50e9fc26b862952);
#
#
#
#         marker_d1a3f9b5b792d6ffa9b23089f1b198bb.bindPopup(popup_3bb660d732de98fbdeb7a5e08328ad93)
#         ;
#
#
#
#
#             marker_cluster_29a526af2a306d12fbf6ecb714d76078.addTo(map_e9d228bab09db786ec099a45cd6a4064);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Creating a Heatmap

# %%
# Import Folium libraries
import folium
from folium.plugins import HeatMap

# Create the map
istanbul_map = folium.Map(location=[41.0082, 28.9784], zoom_start=12)

# Coordinates of historical sites in Istanbul
tourist_coords = [
    [41.0084, 28.9799],  # Hagia Sophia
    [41.0115, 28.9833],  # Topkapi Palace
    [41.0115, 28.9584],  # Blue Mosque
    [41.0085, 28.9799],  # Basilica Cistern
    [41.0257, 28.9744]   # Galata Tower
]

# Create and add HeatMap layer to the map
HeatMap(data=tourist_coords, radius=15).add_to(istanbul_map)

# Display the map
istanbul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d0d7037e5b6b0bfc93f52f360838e2a8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d0d7037e5b6b0bfc93f52f360838e2a8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d0d7037e5b6b0bfc93f52f360838e2a8 = L.map(
#                 &quot;map_d0d7037e5b6b0bfc93f52f360838e2a8&quot;,
#                 {
#                     center: [41.0082, 28.9784],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e5676d1ffba27bca05f53a74b2e1a4b8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_e5676d1ffba27bca05f53a74b2e1a4b8.addTo(map_d0d7037e5b6b0bfc93f52f360838e2a8);
#
#
#             var heat_map_6c0a5fa9f262f3a99a2e5d7e8381826c = L.heatLayer(
#                 [[41.0084, 28.9799], [41.0115, 28.9833], [41.0115, 28.9584], [41.0085, 28.9799], [41.0257, 28.9744]],
#                 {&quot;blur&quot;: 15, &quot;maxZoom&quot;: 18, &quot;minOpacity&quot;: 0.5, &quot;radius&quot;: 15}
#             );
#
#
#             heat_map_6c0a5fa9f262f3a99a2e5d7e8381826c.addTo(map_d0d7037e5b6b0bfc93f52f360838e2a8);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Import Folium libraries
import folium
from folium.plugins import HeatMap

# Coordinates of historical sites in Istanbul
istanbul_historical_sites = {
    "Hagia Sophia": [41.0084, 28.9799],
    "Topkapi Palace": [41.0115, 28.9833],
    "Suleymaniye Mosque": [41.0115, 28.9584],
    "Basilica Cistern": [41.0085, 28.9799],
    "Galata Tower": [41.0257, 28.9744]
}

# Create the map
istanbul_map = folium.Map(location=[41.0082, 28.9784], zoom_start=12)

# Generate HeatMap data
heat_data = [[location[0], location[1]] for location in istanbul_historical_sites.values()]

# Create and add HeatMap layer to the map
HeatMap(heat_data).add_to(istanbul_map)

# Display the map
istanbul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a2c90ba4271f7e1257e339d0ddefb699 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a2c90ba4271f7e1257e339d0ddefb699&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a2c90ba4271f7e1257e339d0ddefb699 = L.map(
#                 &quot;map_a2c90ba4271f7e1257e339d0ddefb699&quot;,
#                 {
#                     center: [41.0082, 28.9784],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0e8a5de2329f21e679ec0ae23d500ce7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_0e8a5de2329f21e679ec0ae23d500ce7.addTo(map_a2c90ba4271f7e1257e339d0ddefb699);
#
#
#             var heat_map_727b6bf2d0eb00b6b97664041d87a0ff = L.heatLayer(
#                 [[41.0084, 28.9799], [41.0115, 28.9833], [41.0115, 28.9584], [41.0085, 28.9799], [41.0257, 28.9744]],
#                 {&quot;blur&quot;: 15, &quot;maxZoom&quot;: 18, &quot;minOpacity&quot;: 0.5, &quot;radius&quot;: 25}
#             );
#
#
#             heat_map_727b6bf2d0eb00b6b97664041d87a0ff.addTo(map_a2c90ba4271f7e1257e339d0ddefb699);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Location Search Feature

# %% [markdown]
# The Geocoder plugin is added to the map to enable location search functionality.
# - collapsed parameter determines whether the search box is open or closed. If set to
# - False, the search box is open by default.
# -  position parameter sets the position of the search box on the map. It can be set to values like "topleft", "topright", "bottomleft", "bottomright".
# - add_marker parameter determines whether search results are marked on the map. If set to True, the search results are marked.

# %%
# Import Folium libraries
import folium

# Create the map
m = folium.Map(location=[41.015, 28.979], zoom_start=13)

# Add Geocoder plugin to enable location search on the map
folium.plugins.Geocoder(collapsed=False, position="topleft", add_marker=True).add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9a5182c884d290c7a0c9cdec0c690cf5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9a5182c884d290c7a0c9cdec0c690cf5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9a5182c884d290c7a0c9cdec0c690cf5 = L.map(
#                 &quot;map_9a5182c884d290c7a0c9cdec0c690cf5&quot;,
#                 {
#                     center: [41.015, 28.979],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4864b13bbad5d47cb1d41d0bdce05a99 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_4864b13bbad5d47cb1d41d0bdce05a99.addTo(map_9a5182c884d290c7a0c9cdec0c690cf5);
#
#
#
#             var geocoderOpts_geocoder_b8d4af8026974c0e77184d6a073b7803 = {&quot;collapsed&quot;: false, &quot;defaultMarkGeocode&quot;: true, &quot;position&quot;: &quot;topleft&quot;, &quot;provider&quot;: &quot;nominatim&quot;, &quot;providerOptions&quot;: {}, &quot;zoom&quot;: 11};
#
#             // note: geocoder name should start with lowercase
#             var geocoderName_geocoder_b8d4af8026974c0e77184d6a073b7803 = geocoderOpts_geocoder_b8d4af8026974c0e77184d6a073b7803[&quot;provider&quot;];
#
#             var customGeocoder_geocoder_b8d4af8026974c0e77184d6a073b7803 = L.Control.Geocoder[ geocoderName_geocoder_b8d4af8026974c0e77184d6a073b7803 ](
#                 geocoderOpts_geocoder_b8d4af8026974c0e77184d6a073b7803[&#x27;providerOptions&#x27;]
#             );
#             geocoderOpts_geocoder_b8d4af8026974c0e77184d6a073b7803[&quot;geocoder&quot;] = customGeocoder_geocoder_b8d4af8026974c0e77184d6a073b7803;
#
#             L.Control.geocoder(
#                 geocoderOpts_geocoder_b8d4af8026974c0e77184d6a073b7803
#             ).on(&#x27;markgeocode&#x27;, function(e) {
#                 var zoom = geocoderOpts_geocoder_b8d4af8026974c0e77184d6a073b7803[&#x27;zoom&#x27;] || map_9a5182c884d290c7a0c9cdec0c690cf5.getZoom();
#                 map_9a5182c884d290c7a0c9cdec0c690cf5.setView(e.geocode.center, zoom);
#             }).addTo(map_9a5182c884d290c7a0c9cdec0c690cf5);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Full-Screen View of the Map

# %% [markdown]
# The FullscreenControl plugin is added to the map to enable fullscreen functionality. It adds a button on the map that allows users to view the map in fullscreen mode.
# position parameter sets the position of the fullscreen button on the map. It is set to 'topright', meaning the button will appear at the top right corner of the map.

# %%
import folium
from folium import plugins

# Create the map
istanbul_map = folium.Map(location=[41.015137, 28.979530], zoom_start=12)

# Add Fullscreen plugin
plugins.Fullscreen().add_to(istanbul_map)

# Display the map
istanbul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3d70096a65eb75d590d3a4d0584d0661 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3d70096a65eb75d590d3a4d0584d0661&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3d70096a65eb75d590d3a4d0584d0661 = L.map(
#                 &quot;map_3d70096a65eb75d590d3a4d0584d0661&quot;,
#                 {
#                     center: [41.015137, 28.97953],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9f52265354b1a04072325ed907a123a9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_9f52265354b1a04072325ed907a123a9.addTo(map_3d70096a65eb75d590d3a4d0584d0661);
#
#
#             L.control.fullscreen(
#                 {&quot;forceSeparateButton&quot;: false, &quot;position&quot;: &quot;topleft&quot;, &quot;title&quot;: &quot;Full Screen&quot;, &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;}
#             ).addTo(map_3d70096a65eb75d590d3a4d0584d0661);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Add Fullscreen Plugin: We add the Fullscreen plugin to the map using the plugins.Fullscreen().add_to() method. This plugin adds a button to the map interface, allowing users to view the map in fullscreen mode.

# %% [markdown]
# ## Adding Drawing Tools

# %% [markdown]
# Add Drawing Tools: We add drawing tools to the map using plugins.Draw(export=True). This provides users with the ability to draw shapes on the map.

# %%
# Import Folium libraries
import folium
from folium import plugins

# Create a new map
m = folium.Map(location=[40.7128, -74.0060], zoom_start=10)

# Add drawing tools
draw = plugins.Draw(export=True)
# folium.Draw(): Provides drawing tools to users.

draw.add_to(m)

# Show the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cec3fde3efcf0190f2eba3f8b8b01b6b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#
#             &lt;style&gt;
#                 #export {
#                     position: absolute;
#                     top: 5px;
#                     right: 10px;
#                     z-index: 999;
#                     background: white;
#                     color: black;
#                     padding: 6px;
#                     border-radius: 4px;
#                     font-family: &#x27;Helvetica Neue&#x27;;
#                     cursor: pointer;
#                     font-size: 12px;
#                     text-decoration: none;
#                     top: 90px;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cec3fde3efcf0190f2eba3f8b8b01b6b&quot; &gt;&lt;/div&gt;
#
#     &lt;a href=&#x27;#&#x27; id=&#x27;export&#x27;&gt;Export&lt;/a&gt;
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cec3fde3efcf0190f2eba3f8b8b01b6b = L.map(
#                 &quot;map_cec3fde3efcf0190f2eba3f8b8b01b6b&quot;,
#                 {
#                     center: [40.7128, -74.006],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_53ef02ff98a78f14a986e91c4af060f1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_53ef02ff98a78f14a986e91c4af060f1.addTo(map_cec3fde3efcf0190f2eba3f8b8b01b6b);
#
#
#             var options = {
#               position: &quot;topleft&quot;,
#               draw: {},
#               edit: {},
#             }
#             // FeatureGroup is to store editable layers.
#             var drawnItems_draw_control_2d57cbe801b28f2c1be879e35073a395 = new L.featureGroup().addTo(
#                 map_cec3fde3efcf0190f2eba3f8b8b01b6b
#             );
#             options.edit.featureGroup = drawnItems_draw_control_2d57cbe801b28f2c1be879e35073a395;
#             var draw_control_2d57cbe801b28f2c1be879e35073a395 = new L.Control.Draw(
#                 options
#             ).addTo( map_cec3fde3efcf0190f2eba3f8b8b01b6b );
#             map_cec3fde3efcf0190f2eba3f8b8b01b6b.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 drawnItems_draw_control_2d57cbe801b28f2c1be879e35073a395.addLayer(layer);
#              });
#             map_cec3fde3efcf0190f2eba3f8b8b01b6b.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems_draw_control_2d57cbe801b28f2c1be879e35073a395.addLayer(e.layer);
#             });
#
#             document.getElementById(&#x27;export&#x27;).onclick = function(e) {
#                 var data = drawnItems_draw_control_2d57cbe801b28f2c1be879e35073a395.toGeoJSON();
#                 var convertedData = &#x27;text/json;charset=utf-8,&#x27;
#                     + encodeURIComponent(JSON.stringify(data));
#                 document.getElementById(&#x27;export&#x27;).setAttribute(
#                     &#x27;href&#x27;, &#x27;data:&#x27; + convertedData
#                 );
#                 document.getElementById(&#x27;export&#x27;).setAttribute(
#                     &#x27;download&#x27;, &quot;data.geojson&quot;
#                 );
#             }
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # <font color='red'> <b>In which areas are our customers concentrated in New York?</b><font color='red'>

# %%
#  Turn customer data into a list
customers = [
    {"customer_id": 1, "region": "Queens", "enlem": 41.4036, "boylam": 2.1743},
    {"customer_id": 2, "region": "Manhattan", "enlem": 40.7128, "boylam": -74.0060},
    {"customer_id": 3, "region": "Brooklyn", "enlem": 40.6781, "boylam": -73.9756},
    {"customer_id": 4, "region": "Queens", "enlem": 41.4036, "boylam": 2.1606},
    {"customer_id": 5, "region": "Manhattan", "enlem": 40.7128, "boylam": -74.0060},
    {"customer_id": 6, "region": "Bronx", "enlem": 40.8448, "boylam": -73.8648},  # Eklediğiniz yeni müşteri
    {"customer_id": 7, "region": "Staten Island", "enlem": 40.5795, "boylam": -74.1502}  # Eklediğiniz yeni müşteri
]

# Import Folium libraries
import folium

# Create a New York map
new_york_map = folium.Map(location=[40.7128, -74.0060], zoom_start=10)

# Dictionary of region coordinates
region_coordinates = {
    "Queens": (40.7282, -73.7949),
    "Manhattan": (40.7831, -73.9712),
    "Brooklyn": (40.6782, -73.9442),
    "Bronx": (40.8448, -73.8648),  
    "Staten Island": (40.5795, -74.1502) 
}

# Add customer data to the map
for customer in customers:
    # Gracefully handle missing regions (Option 1)
    location = region_coordinates.get(customer["region"])
    if location:
        folium.Marker(location=location, popup=f"{customer['customer_id']} - {customer['region']}").add_to(new_york_map)
    else:
        # Add a default marker for missing regions (optional)
        default_location = (40.7128, -74.0060)  # New York City center (example)
        folium.Marker(location=default_location, popup=f"{customer['customer_id']} - **{customer['region']}**").add_to(new_york_map)

# Show the map
new_york_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f2de9e6720f9a499948ce54e54e7d40f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f2de9e6720f9a499948ce54e54e7d40f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f2de9e6720f9a499948ce54e54e7d40f = L.map(
#                 &quot;map_f2de9e6720f9a499948ce54e54e7d40f&quot;,
#                 {
#                     center: [40.7128, -74.006],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a572bc7e37486698bd8167fb1c82d423 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_a572bc7e37486698bd8167fb1c82d423.addTo(map_f2de9e6720f9a499948ce54e54e7d40f);
#
#
#             var marker_4297e1dde74280082bb6fb5dd34dab3e = L.marker(
#                 [40.7282, -73.7949],
#                 {}
#             ).addTo(map_f2de9e6720f9a499948ce54e54e7d40f);
#
#
#         var popup_4c8971be20b7f897e15563cdcfba4919 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f51233a2ac53b17189c243c30b1ca3e7 = $(`&lt;div id=&quot;html_f51233a2ac53b17189c243c30b1ca3e7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1 - Queens&lt;/div&gt;`)[0];
#                 popup_4c8971be20b7f897e15563cdcfba4919.setContent(html_f51233a2ac53b17189c243c30b1ca3e7);
#
#
#
#         marker_4297e1dde74280082bb6fb5dd34dab3e.bindPopup(popup_4c8971be20b7f897e15563cdcfba4919)
#         ;
#
#
#
#
#             var marker_4bc30323a6b00c4f54366345909e27c7 = L.marker(
#                 [40.7831, -73.9712],
#                 {}
#             ).addTo(map_f2de9e6720f9a499948ce54e54e7d40f);
#
#
#         var popup_472d046d167b47effbf122e6f01210e2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6a860be471bec82ef7eb83b5ea67e51a = $(`&lt;div id=&quot;html_6a860be471bec82ef7eb83b5ea67e51a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;2 - Manhattan&lt;/div&gt;`)[0];
#                 popup_472d046d167b47effbf122e6f01210e2.setContent(html_6a860be471bec82ef7eb83b5ea67e51a);
#
#
#
#         marker_4bc30323a6b00c4f54366345909e27c7.bindPopup(popup_472d046d167b47effbf122e6f01210e2)
#         ;
#
#
#
#
#             var marker_8dfc1300f18c8a616f1084df529f7531 = L.marker(
#                 [40.6782, -73.9442],
#                 {}
#             ).addTo(map_f2de9e6720f9a499948ce54e54e7d40f);
#
#
#         var popup_015844cde96f91b388c6027e76bd47fa = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_573af08a87135e723c7bd31a2d422759 = $(`&lt;div id=&quot;html_573af08a87135e723c7bd31a2d422759&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;3 - Brooklyn&lt;/div&gt;`)[0];
#                 popup_015844cde96f91b388c6027e76bd47fa.setContent(html_573af08a87135e723c7bd31a2d422759);
#
#
#
#         marker_8dfc1300f18c8a616f1084df529f7531.bindPopup(popup_015844cde96f91b388c6027e76bd47fa)
#         ;
#
#
#
#
#             var marker_c45937ba29d8e87a34c0778966da04ae = L.marker(
#                 [40.7282, -73.7949],
#                 {}
#             ).addTo(map_f2de9e6720f9a499948ce54e54e7d40f);
#
#
#         var popup_1b4fa853c578158a19cab7b1f388a3d7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2b16c46efc064ea2ac2ad5cbc07aa725 = $(`&lt;div id=&quot;html_2b16c46efc064ea2ac2ad5cbc07aa725&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;4 - Queens&lt;/div&gt;`)[0];
#                 popup_1b4fa853c578158a19cab7b1f388a3d7.setContent(html_2b16c46efc064ea2ac2ad5cbc07aa725);
#
#
#
#         marker_c45937ba29d8e87a34c0778966da04ae.bindPopup(popup_1b4fa853c578158a19cab7b1f388a3d7)
#         ;
#
#
#
#
#             var marker_85fba83e39f37f399117a52a8ea8e090 = L.marker(
#                 [40.7831, -73.9712],
#                 {}
#             ).addTo(map_f2de9e6720f9a499948ce54e54e7d40f);
#
#
#         var popup_11534d5d45b641b5f3e2e1a8aa53896a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_eb434565ee8dc01b94f9eaebd280222d = $(`&lt;div id=&quot;html_eb434565ee8dc01b94f9eaebd280222d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;5 - Manhattan&lt;/div&gt;`)[0];
#                 popup_11534d5d45b641b5f3e2e1a8aa53896a.setContent(html_eb434565ee8dc01b94f9eaebd280222d);
#
#
#
#         marker_85fba83e39f37f399117a52a8ea8e090.bindPopup(popup_11534d5d45b641b5f3e2e1a8aa53896a)
#         ;
#
#
#
#
#             var marker_4c044998f35b353df650278393454650 = L.marker(
#                 [40.8448, -73.8648],
#                 {}
#             ).addTo(map_f2de9e6720f9a499948ce54e54e7d40f);
#
#
#         var popup_ce3

# %% [markdown]
# # <font color='red'> <b>What are the 5 most visited tourist destinations in Spain?</b><font color='red'>

# %%
# List of 5 most visited places in Spain
places_to_visit = [
    {"place_name": "Sagrada Familia", "region": "Barcelona", "latitude": 41.4036, "longitude": 2.1743},
    {"place_name": "Alhambra", "region": "Granada", "latitude": 38.9719, "longitude": -3.8915},
    {"place_name": "Prado Museum", "region": "Madrid", "latitude": 40.4167, "longitude": -3.6833},
    {"place_name": "Park Güell", "region": "Barcelona", "latitude": 41.4036, "longitude": 2.1606},
    {"place_name": "Guggenheim Museum Bilbao", "region": "Bilbao", "latitude": 43.2609, "longitude": -2.9257},
]



# Import the Folium library and pandas
import folium
import pandas as pd

# Convert the list of places to a pandas DataFrame
data = pd.DataFrame(places_to_visit)

# Set the coordinates of Spain
spain_coordinates = (40.4002, -3.7501)

# Create a map
spain_map = folium.Map(location=spain_coordinates, zoom_start=6)

# Add the data to the map
for index, row in data.iterrows():
    folium.Marker(location=[row["latitude"], row["longitude"]], 
                  popup=f"{row['place_name']} ({row['region']})").add_to(spain_map)

# Save the map
# spain_map.save("spain_places_to_visit.html")

spain_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1b9a09b562e1521ff2de440284b0b1c5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1b9a09b562e1521ff2de440284b0b1c5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1b9a09b562e1521ff2de440284b0b1c5 = L.map(
#                 &quot;map_1b9a09b562e1521ff2de440284b0b1c5&quot;,
#                 {
#                     center: [40.4002, -3.7501],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b4ab01d7aa0e41126898623a46f465a0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_b4ab01d7aa0e41126898623a46f465a0.addTo(map_1b9a09b562e1521ff2de440284b0b1c5);
#
#
#             var marker_e5513fb98f469b93e3e7769572272ecb = L.marker(
#                 [41.4036, 2.1743],
#                 {}
#             ).addTo(map_1b9a09b562e1521ff2de440284b0b1c5);
#
#
#         var popup_bfbd8365247c0572634064866028da87 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_51ed925f48489e020a0bf69788419274 = $(`&lt;div id=&quot;html_51ed925f48489e020a0bf69788419274&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sagrada Familia (Barcelona)&lt;/div&gt;`)[0];
#                 popup_bfbd8365247c0572634064866028da87.setContent(html_51ed925f48489e020a0bf69788419274);
#
#
#
#         marker_e5513fb98f469b93e3e7769572272ecb.bindPopup(popup_bfbd8365247c0572634064866028da87)
#         ;
#
#
#
#
#             var marker_7116ad590bb71ac3fc6de33a56cb8b52 = L.marker(
#                 [38.9719, -3.8915],
#                 {}
#             ).addTo(map_1b9a09b562e1521ff2de440284b0b1c5);
#
#
#         var popup_56b8afbf3f2b1f13e078c5ed837a43f4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8bdc5864bc79e38386979a16043aea36 = $(`&lt;div id=&quot;html_8bdc5864bc79e38386979a16043aea36&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Alhambra (Granada)&lt;/div&gt;`)[0];
#                 popup_56b8afbf3f2b1f13e078c5ed837a43f4.setContent(html_8bdc5864bc79e38386979a16043aea36);
#
#
#
#         marker_7116ad590bb71ac3fc6de33a56cb8b52.bindPopup(popup_56b8afbf3f2b1f13e078c5ed837a43f4)
#         ;
#
#
#
#
#             var marker_1c6bd54a52eaf68752a8e0fefbbd65bd = L.marker(
#                 [40.4167, -3.6833],
#                 {}
#             ).addTo(map_1b9a09b562e1521ff2de440284b0b1c5);
#
#
#         var popup_b2651c9c47b23fb776e94f11684facda = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8e46dd3c4ba58ea9b73de55b9db665a5 = $(`&lt;div id=&quot;html_8e46dd3c4ba58ea9b73de55b9db665a5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Prado Museum (Madrid)&lt;/div&gt;`)[0];
#                 popup_b2651c9c47b23fb776e94f11684facda.setContent(html_8e46dd3c4ba58ea9b73de55b9db665a5);
#
#
#
#         marker_1c6bd54a52eaf68752a8e0fefbbd65bd.bindPopup(popup_b2651c9c47b23fb776e94f11684facda)
#         ;
#
#
#
#
#             var marker_c27fc01b27d8c08de82c60ac4d5495a5 = L.marker(
#                 [41.4036, 2.1606],
#                 {}
#             ).addTo(map_1b9a09b562e1521ff2de440284b0b1c5);
#
#
#         var popup_87657c6d1e908615192731e6c4fe830c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_63ebd41fa470702a7b7cd70f6d7079c6 = $(`&lt;div id=&quot;html_63ebd41fa470702a7b7cd70f6d7079c6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Park Güell (Barcelona)&lt;/div&gt;`)[0];
#                 popup_87657c6d1e908615192731e6c4fe830c.setContent(html_63ebd41fa470702a7b7cd70f6d7079c6);
#
#
#
#         marker_c27fc01b27d8c08de82c60ac4d5495a5.bindPopup(popup_87657c6d1e908615192731e6c4fe830c)
#         ;
#
#
#
#
#             var marker_4b465746239919302e952002c875f046 = L.marker(
#                 [43.2609, -2.9257],
#                 {}
#             ).addTo(map_1b9a09b562e1521ff2de440284b0b1c5);
#
#
#         var popup_b56d5c3ac048674e4be1da991e2fadb9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ec203938dd48b3f5cf02d9ba67183c13 = $(`&lt;div id=&quot;html_ec203938dd48b3f5cf02d9ba67183c13&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Guggenheim Museum Bilbao (Bilbao)&lt;/div&gt;`)[0];
#                 popup_b56d5c3ac048674e4be1da991e2fadb9.setContent(html_ec203938dd48b3f5cf02d9ba67183c13);
#
#
#
#         marker_4b465746239919302e952002c875f046.bindPopup(popup_b56d5c3ac048674e4be1da991e2fadb9)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfulls

# %% [markdown]
# # <font color='red'> <b>Map of Amazon's Top 5 Selling Countries</b><font color='red'>

# %%
# Convert Amazon sales data to a list
amazon_sales = [
    {"country": "US", "sales_amount": 100000000},
    {"country": "DE", "sales_amount": 50000000},
    {"country": "GB", "sales_amount": 40000000},
    {"country": "JP", "sales_amount": 30000000},
    {"country": "FR", "sales_amount": 20000000},
]

import folium

# Create the world map
world_map = folium.Map(location=[0, 0], zoom_start=2)

# Country coordinates
country_coordinates = {
    "US": [37.0902, -95.7129],
    "DE": [51.1657, 10.4515],
    "GB": [55.3781, -3.4360],
    "JP": [36.2048, 138.2529],
    "FR": [46.6034, 1.8883]
}

# Find the country with the highest sales
top_selling_country, top_sales_amount = max([(sale["country"], sale["sales_amount"]) for sale in amazon_sales], key=lambda x: x[1])

# Add markers to the map
for sale in amazon_sales:
    if sale["country"] in country_coordinates:
        popup = f"{sale['country']} - Sales Amount: {sale['sales_amount']:,}"
        folium.Marker(location=country_coordinates[sale["country"]], popup=popup).add_to(world_map)

# Highlight the marker of the top selling country in a different color
if top_selling_country in country_coordinates:
    popup = f"**Top Sales:** {top_selling_country} - {top_sales_amount:,}"
    folium.Marker(location=country_coordinates[top_selling_country], popup=popup, icon=folium.Icon(color='red')).add_to(world_map)

# Save the map
#world_map.save("amazon_sales_map.html")

world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ea530671156e035303354f7c57fec690 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ea530671156e035303354f7c57fec690&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ea530671156e035303354f7c57fec690 = L.map(
#                 &quot;map_ea530671156e035303354f7c57fec690&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_45ce792d60820d878a5516f61865d67a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_45ce792d60820d878a5516f61865d67a.addTo(map_ea530671156e035303354f7c57fec690);
#
#
#             var marker_15907bf6eda0bde2483d308a583f4e80 = L.marker(
#                 [37.0902, -95.7129],
#                 {}
#             ).addTo(map_ea530671156e035303354f7c57fec690);
#
#
#         var popup_9ce6fc1d241a96e1ea52e4978be01bab = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ec1159d85eda2921d32a1d7ace3a2222 = $(`&lt;div id=&quot;html_ec1159d85eda2921d32a1d7ace3a2222&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;US - Sales Amount: 100,000,000&lt;/div&gt;`)[0];
#                 popup_9ce6fc1d241a96e1ea52e4978be01bab.setContent(html_ec1159d85eda2921d32a1d7ace3a2222);
#
#
#
#         marker_15907bf6eda0bde2483d308a583f4e80.bindPopup(popup_9ce6fc1d241a96e1ea52e4978be01bab)
#         ;
#
#
#
#
#             var marker_ab28026482a47b67c88b35b991eb4166 = L.marker(
#                 [51.1657, 10.4515],
#                 {}
#             ).addTo(map_ea530671156e035303354f7c57fec690);
#
#
#         var popup_98451df2fb4d584aabccdb12cf6f59d6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e4e89c1cb115d8db61e70024eb6ff7d9 = $(`&lt;div id=&quot;html_e4e89c1cb115d8db61e70024eb6ff7d9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;DE - Sales Amount: 50,000,000&lt;/div&gt;`)[0];
#                 popup_98451df2fb4d584aabccdb12cf6f59d6.setContent(html_e4e89c1cb115d8db61e70024eb6ff7d9);
#
#
#
#         marker_ab28026482a47b67c88b35b991eb4166.bindPopup(popup_98451df2fb4d584aabccdb12cf6f59d6)
#         ;
#
#
#
#
#             var marker_19646ad30b6f92fdf74f35d670b910c9 = L.marker(
#                 [55.3781, -3.436],
#                 {}
#             ).addTo(map_ea530671156e035303354f7c57fec690);
#
#
#         var popup_af6d3cc22f00ea59a0edb2511cec6e29 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e662fc663c5dd38786a7382ebd245c7c = $(`&lt;div id=&quot;html_e662fc663c5dd38786a7382ebd245c7c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;GB - Sales Amount: 40,000,000&lt;/div&gt;`)[0];
#                 popup_af6d3cc22f00ea59a0edb2511cec6e29.setContent(html_e662fc663c5dd38786a7382ebd245c7c);
#
#
#
#         marker_19646ad30b6f92fdf74f35d670b910c9.bindPopup(popup_af6d3cc22f00ea59a0edb2511cec6e29)
#         ;
#
#
#
#
#             var marker_825a9227650e30ccd4542075fdaf1fe6 = L.marker(
#                 [36.2048, 138.2529],
#                 {}
#             ).addTo(map_ea530671156e035303354f7c57fec690);
#
#
#         var popup_e4cf242775755713059ed2f9d10c0e35 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_45652c960517922db046b025d23ade91 = $(`&lt;div id=&quot;html_45652c960517922db046b025d23ade91&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;JP - Sales Amount: 30,000,000&lt;/div&gt;`)[0];
#                 popup_e4cf242775755713059ed2f9d10c0e35.setContent(html_45652c960517922db046b025d23ade91);
#
#
#
#         marker_825a9227650e30ccd4542075fdaf1fe6.bindPopup(popup_e4cf242775755713059ed2f9d10c0e35)
#         ;
#
#
#
#
#             var marker_3355922bae3037bfca12aaabf7d7f21a = L.marker(
#                 [46.6034, 1.8883],
#                 {}
#             ).addTo(map_ea530671156e035303354f7c57fec690);
#
#
#         var popup_8c109c7e48a29030262bd0e46013c4fd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fe813788dea7a3b305d2b9705dd3130e = $(`&lt;div id=&quot;html_fe813788dea7a3b305d2b9705dd3130e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;FR - Sales Amount: 20,000,000&lt;/div&gt;`)[0];
#                 popup_8c109c7e48a29030262bd0e46013c4fd.setContent(html_fe813788dea7a3b305d2b9705dd3130e);
#
#
#
#         marker_3355922bae3037bfca12aaabf7d7f21a.bindPopup(popup_8c109c7e48a29030262bd0e46013c4fd)
#         ;
#
#
#
#
#             var marker_68af71c5690c8c6dd84eaeccee9d4352 = L.marker(
#                 [37.0902, -95.7129],
#                 {}
#             ).addTo(

# %% [markdown]
# # <font color='red'> <b>The 5 Most Populous Countries by Population Density</b><font color='red'>

# %%
import folium

# Population data
population_data = [
    {"country": "China", "population": 1444215628},
    {"country": "India", "population": 1380004385},
    {"country": "United States", "population": 332975285},
    {"country": "Indonesia", "population": 273523615},
    {"country": "Pakistan", "population": 235309000},
]

# Coordinates of selected countries
country_coordinates = {
    "China": {"latitude": 35.8617, "longitude": 104.1954},
    "India": {"latitude": 20.5937, "longitude": 78.9629},
    "United States": {"latitude": 37.0902, "longitude": -95.7129},
    "Indonesia": {"latitude": -0.7893, "longitude": 113.9213},
    "Pakistan": {"latitude": 30.3753, "longitude": 69.3451}
}

# Create the world map
world_map = folium.Map(location=[0, 0], zoom_start=2)

# Find the most populous country
most_populous_country = max(population_data, key=lambda x: x["population"])

# Add markers to the map
for country_data in population_data:
    country = country_data["country"]
    popup = f"{country} - Population: {country_data['population']:,}"
    color = 'red' if country_data == most_populous_country else 'blue'
    if country in country_coordinates:
        coordinates = country_coordinates[country]
        folium.Marker(location=[coordinates["latitude"], coordinates["longitude"]], popup=popup, icon=folium.Icon(color=color)).add_to(world_map)

# Show map
world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1598118ccc73e1c2d32c698b4bfe8005 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1598118ccc73e1c2d32c698b4bfe8005&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1598118ccc73e1c2d32c698b4bfe8005 = L.map(
#                 &quot;map_1598118ccc73e1c2d32c698b4bfe8005&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d26abc8b81f677c20096068eee5893ec = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_d26abc8b81f677c20096068eee5893ec.addTo(map_1598118ccc73e1c2d32c698b4bfe8005);
#
#
#             var marker_cf51da67f365c10373c004371657928c = L.marker(
#                 [35.8617, 104.1954],
#                 {}
#             ).addTo(map_1598118ccc73e1c2d32c698b4bfe8005);
#
#
#             var icon_c42391d677d080ea73324e1ae50354fd = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_cf51da67f365c10373c004371657928c.setIcon(icon_c42391d677d080ea73324e1ae50354fd);
#
#
#         var popup_a95314d5c1a1e173c69f502d02481f93 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_db568dbccbba043ed5dec94e4d0c7ce9 = $(`&lt;div id=&quot;html_db568dbccbba043ed5dec94e4d0c7ce9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;China - Population: 1,444,215,628&lt;/div&gt;`)[0];
#                 popup_a95314d5c1a1e173c69f502d02481f93.setContent(html_db568dbccbba043ed5dec94e4d0c7ce9);
#
#
#
#         marker_cf51da67f365c10373c004371657928c.bindPopup(popup_a95314d5c1a1e173c69f502d02481f93)
#         ;
#
#
#
#
#             var marker_134dbea0a5690fd233c4614e5cafdddd = L.marker(
#                 [20.5937, 78.9629],
#                 {}
#             ).addTo(map_1598118ccc73e1c2d32c698b4bfe8005);
#
#
#             var icon_7bc021b7271ad1bb02a158a74ed9e069 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_134dbea0a5690fd233c4614e5cafdddd.setIcon(icon_7bc021b7271ad1bb02a158a74ed9e069);
#
#
#         var popup_223fd409e1cc03b6ae7080c198fc6984 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_49424408da44c09d29501fba7c84c5b4 = $(`&lt;div id=&quot;html_49424408da44c09d29501fba7c84c5b4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;India - Population: 1,380,004,385&lt;/div&gt;`)[0];
#                 popup_223fd409e1cc03b6ae7080c198fc6984.setContent(html_49424408da44c09d29501fba7c84c5b4);
#
#
#
#         marker_134dbea0a5690fd233c4614e5cafdddd.bindPopup(popup_223fd409e1cc03b6ae7080c198fc6984)
#         ;
#
#
#
#
#             var marker_323f42bee9142a7da44042594db37c1c = L.marker(
#                 [37.0902, -95.7129],
#                 {}
#             ).addTo(map_1598118ccc73e1c2d32c698b4bfe8005);
#
#
#             var icon_b5e164d981eb6c671cbbdc41a478af34 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_323f42bee9142a7da44042594db37c1c.setIcon(icon_b5e164d981eb6c671cbbdc41a478af34);
#
#
#         var popup_6042880499b683a0882a235e659ecc52 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4b8ff9c808df1699839ab82a20db801d = $(`&lt;div id=&quot;html_4b8ff9c808df1699839ab82a20db801d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;United States - Population: 332,975,285&lt;/div&gt;`)[0];
#                 popup_6042880499b683a0882a235e659ecc52.setContent(html_4b8ff9c808df1699839ab82a20db801d);
#
#
#
#         marker_323f42bee9142a7da44042594db37c1c.bindPopup(popup_6042880499b683a0882a235e659ecc52)
#         ;
#
#
#
#
#             var marker_8d4cd38ae16acd544fe951e59ee7765d = L.marker(
#                 [-0.7893, 113.9213],
#                 {}
#             ).addTo(map_1598118ccc73e1c2d32c698b4bfe8005);
#
#
#             var icon_22cea47a8dd7d038921dcde5dcaad820 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColo

# %% [markdown]
# # <p style="background-color:red;font-family:arial;font-size:110%;color:white;text-align:center;border-radius:20px 20px;"><b>Thank you in the hope that it will be useful
# </b></p>
#
# <b>If you want to be the first to be informed about new projects, please do not forget to follow us </b>[Linkedin](https://www.linkedin.com/in/fatma-nur-azman/) | [Kaggle](https://www.kaggle.com/fnurazman) | [Tableau](https://public.tableau.com/app/profile/fatma.nur.azman/vizzes)
